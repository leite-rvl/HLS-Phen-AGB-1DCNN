# %%
''' 
Having issues with multiprocessing doing multiple concurrent requests?

<p>CMR Search rate exceeded. Please refer to the following for guidance: https://cmr.earthdata.nasa.gov/search/site/docs/search/api.html#request-moderation

many STAC queries - per month/year, per product, incrementing the max_cloud

add time.sleep() between requests ?

Reduce request count?
- Instead of increasing cloud threshold single threshold?

'''

# %%
import os

from pathlib import Path
from datetime import datetime
from calendar import monthrange

import fiona

import multiprocessing as mp

import geopandas as gpd

import copy

# %%
import sys
sys.path.append('/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib')
import plotlib
from mosaiclib import *

# %%
import rasterio
from rasterio.plot import show_hist, show
import numpy as np
import matplotlib.pyplot as plt

# %%
import multiprocessing as mp

num_cores = mp.cpu_count()
print(f"Number of CPU cores: {num_cores}")

import psutil

mem = psutil.virtual_memory()
print(f"Total memory: {mem.total / 1e9:.2f} GB")
print(f"Available memory: {mem.available / 1e9:.2f} GB")
# Out:
# Number of CPU cores: 32
# Total memory: 267.33 GB
# Available memory: 256.46 GB

# %%
# Functions 
def wrapper_composite(params):

    FOCAL_TILE = params.get('FOCAL_TILE')
    SAT_API = params.get('SAT_API')
    MS_COMP_TYPE = params.get('MS_COMP_TYPE')
    YEAR = params.get('YEAR')
    MIN_N_FILT_RESULTS = params.get('MIN_N_FILT_RESULTS')
    SEASON_START = params.get('SEASON_START')
    SEASON_STOP = params.get('SEASON_STOP')
    # INDEX_FN = params.get('INDEX_FN')
    # INDEX_LYR = params.get('INDEX_LYR')
    
    STAT = params.get('STAT')
    STAT_PCT = params.get('STAT_PCT')
    TARGET_SPECTRAL = params.get('TARGET_SPECTRAL')

    INDEX_FN =  params.get('INDEX_FN') #'https://maap-ops-workspace.s3.amazonaws.com/shared/montesano/databank/boreal_tiles_v004.gpkg'
    INDEX_LYR = params.get('INDEX_LYR') # 'boreal_tiles_v004'
    
    YEAR_START, YEAR_STOP = (YEAR, YEAR)
    HLS_PRODUCT = params.get('HLS_PRODUCT') #HLS_PRODUCT = 'H30'
    MAX_CLOUDS = params.get('MAX_CLOUDS') #MAX_CLOUDS = 0

    OUTDIR = params.get('OUTDIR') #'/projects/my-private-bucket/tmp/mask_test_keep_snow'
    
    args = f"--in_tile_fn {INDEX_FN} \
        --in_tile_layer {INDEX_LYR} \
        --sat_api {SAT_API} \
        --tile_buffer_m 0 \
        --in_tile_num {FOCAL_TILE} \
        --output_dir {OUTDIR} \
        -sy {YEAR_START} -ey {YEAR_STOP} -smd {SEASON_START} -emd {SEASON_STOP} -mc {MAX_CLOUDS} \
        --composite_type {MS_COMP_TYPE} \
        --hls_product {HLS_PRODUCT} \
        --thresh_min_ndvi -1 \
        --min_n_filt_results {MIN_N_FILT_RESULTS} \
        --stat {STAT} \
        --stat_pct {STAT_PCT} \
        --target_spectral_index {TARGET_SPECTRAL}"
    args += " --do_indices"
    #args += " --search_only"
    # args += " --rangelims_red 0.01 0.1" # the default now effectively no limit [-1e9, 1e9]
    args += " --rangelims_red 0.01 1" # the default now effectively no limit [-1e9, 1e9]
    
    # cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite.py {args}'
    # cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_multip.py {args}'
    cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py {args}'
    #!echo $cmd
    # !eval $cmd

    fn = f'{OUTDIR}/{MS_COMP_TYPE}_{FOCAL_TILE}_{SEASON_START}_{SEASON_STOP}_{YEAR_START}_{YEAR_STOP}_{STAT}{TARGET_SPECTRAL}.tif'
    if STAT == 'percentile':
        fn = f'{OUTDIR}/{MS_COMP_TYPE}_{FOCAL_TILE}_{SEASON_START}_{SEASON_STOP}_{YEAR_START}_{YEAR_STOP}_{STAT}{STAT_PCT}{TARGET_SPECTRAL}.tif'
    #rescaled_multiband_fn = os.path.join(os.path.dirname(fn), os.path.basename(fn).replace('.tif','_rescaled_3band_temp.tif'))
    # plotlib.rescale_multiband_for_plot(fn, rescaled_multiband_fn, bandlist = [5,7,3], pct=[20,90], nodata=-9999.0) 

    return fn

# %%
# Define input and output paths
INDEX_FN = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg' 
BASE_OUTDIR = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95'

# %%
# Set default parameters
SAT_API = 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'
MS_COMP_TYPE = 'HLS'
HLS_PRODUCT = 'H30'

# STAT = 'max'
STAT = 'percentile'

# TARGET_SPECTRAL = 'ndvi'
TARGET_SPECTRAL = 'evi2'
STAT_PCT = 95.0

MIN_N_FILT_RESULTS = 10
MAX_CLOUDS = 0 # Threshold of max clouds to start search, e.g. when set to 0 it starts at 0% of cloud cover and go up to 90%

# %%
# Get first Layer name (First layer is used as default)
layer_names = fiona.listlayers(INDEX_FN)
# Get the first layer name
first_layer_name = layer_names[0]
INDEX_LYR = first_layer_name

# %%
# Define parameters
params = {
    'SAT_API': SAT_API,
    'HLS_PRODUCT': HLS_PRODUCT,
    'MS_COMP_TYPE': MS_COMP_TYPE,
    'MAX_CLOUDS': MAX_CLOUDS,
    'MIN_N_FILT_RESULTS': MIN_N_FILT_RESULTS,
    'STAT': STAT,
    'STAT_PCT': STAT_PCT,
    'TARGET_SPECTRAL': TARGET_SPECTRAL,
    'INDEX_FN': INDEX_FN,
    'INDEX_LYR': INDEX_LYR,
}

# %%
# Define year
years = [2022]

# Get all tiles IDs
with fiona.open(INDEX_FN, layer=0) as src:
    tiles = [feature["properties"]["tile_num"] for feature in src]
    
tiles_gpkg = gpd.read_file(INDEX_FN)
tiles = tiles_gpkg["tile_num"].tolist()
# # tiles

# %%
len(tiles)
# Out:
# 1561

# %%
# Select tiles to run
# tiles_run = tiles

tiles_run = tiles[3:4]
tiles_run
# Out:
# [4]

# %%
# years = [2022]
years = [2018,2019,2020,2021,2022]
# years = [2015,2016,2017]

# type(years)

# %%
# %%time
# Create parameter list and create output directories
# This is set up to do monthly composites
params_list = []
for tile in tiles_run: 
    for year in years:
        # for month in range(2, 4):
        for month in range(1, 13):
            start_day = f"{month:02d}-01"
            end_day = f"{month:02d}-{monthrange(year, month)[1]:02d}"
    
            # output directory for specific run
            # outdir = f'{BASE_OUTDIR}/tile_{tile:03d}/{year}/{month:02d}'
            outdir = f'{BASE_OUTDIR}/tile_{tile:03d}/{year}/'
            
            os.makedirs(outdir, exist_ok=True)
    
            run_params = copy.deepcopy(params)
            run_params.update({
                'FOCAL_TILE': tile,
                'YEAR': year,
                'SEASON_START': start_day,
                'SEASON_STOP': end_day,
                'OUTDIR': str(outdir)
            })
    
            params_list.append(run_params)
# Out:
# CPU times: user 0 ns, sys: 3.93 ms, total: 3.93 ms
# Wall time: 571 ms

# %%
len(params_list)
# Out:
# 60

# %%
# %%time
# mp.cpu_count() - 1
# with mp.Pool(processes= 5) as pool:
#     fn_list = pool.map(wrapper_composite, params_list)
with mp.Pool(processes= 12) as pool:
    fn_list = pool.map(wrapper_composite, params_list)
# Out:
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2019-05-01T00:00:00Z 2019-05-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2019-07-01T00:00:00Z 2019-07-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2018-01-01T00:00:00Z 2018-01-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2018-09-01T00:00:00Z 2018-09-30T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2018-05-01T00:00:00Z 2018-05-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2018-03-01T00:00:00Z 2018-03-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				0
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2018-11-01T00:00:00Z 2018-11-30T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2019-03-01T00:00:00Z 2019-03-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2018-07-01T00:00:00Z 2018-07-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2019-11-01T00:00:00Z 2019-11-30T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2019-09-01T00:00:00Z 2019-09-30T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSS30_2.0):				0
# 	Only 0 HLS scenes using lte 5% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				0
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2019-01-01T00:00:00Z 2019-01-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				0
# partial results (HLSL30_2.0):				6
# partial results (HLSL30_2.0):				0
# partial results (HLSL30_2.0):				0
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				0
# 	Only 0 HLS scenes using lte 5% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				1
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				0
# 	Only 2 HLS scenes using lte 5% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				0
# 	Only 0 HLS scenes using lte 5% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				0
# 	Only 0 HLS scenes using lte 10% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSS30_2.0):				0
# 	Only 2 HLS scenes using lte 5% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				2
# 	Only 2 HLS scenes using lte 5% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				3
# 	Only 9 HLS scenes using lte 5% cloudcover for 2018-05-01T00:00:00Z-2018-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 5% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 5% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 5% cloudcover for 2018-07-01T00:00:00Z-2018-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				0
# 	Only 2 HLS scenes using lte 10% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				2
# 	Only 3 HLS scenes using lte 5% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				1
# 	Only 3 HLS scenes using lte 10% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				1
# partial results (HLSL30_2.0):				6
# partial results (HLSS30_2.0):				0
# 	Only 0 HLS scenes using lte 15% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 5% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 10% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSS30_2.0):				1
# 	Only 3 HLS scenes using lte 10% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				4
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				1
# 	Only 3 HLS scenes using lte 10% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSS30_2.0):				3
# 	Only 4 HLS scenes using lte 10% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 15% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 10% cloudcover for 2018-07-01T00:00:00Z-2018-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 10% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				3
# HLS.L30.T21KXQ.2018124T134034.v2.0
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				2
# 	Only 3 HLS scenes using lte 10% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# HLS.L30.T21KXP.2018124T134034.v2.0
# partial results (HLSL30_2.0):				2
# HLS.L30.T21KXQ.2018133T133417.v2.0
# HLS.L30.T21KXP.2018133T133417.v2.0
# HLS.L30.T21KXQ.2018149T133404.v2.0
# partial results (HLSL30_2.0):				2
# HLS.L30.T21KXP.2018149T133404.v2.0
# HLS.S30.T21KXP.2018124T135109.v2.0
# partial results (HLSL30_2.0):				2
# HLS.S30.T21KXQ.2018124T135109.v2.0
# HLS.S30.T21KXP.2018134T135109.v2.0
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				1
# 	Only 2 HLS scenes using lte 20% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# HLS.S30.T21KXP.2018149T135111.v2.0
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 15% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSL30_2.0):				1
#
# Total # of scenes for composite:		10
# partial results (HLSS30_2.0):				1
# 	Only 3 HLS scenes using lte 15% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 10% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				4
# Creating evi2 stack with HLS ...
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 15% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 15% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 20% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSS30_2.0):				1
# 	Only 3 HLS scenes using lte 15% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 15% cloudcover for 2018-07-01T00:00:00Z-2018-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				3
# 	Only 4 HLS scenes using lte 15% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 15% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				1
# 	Only 2 HLS scenes using lte 25% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 15% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSS30_2.0):				4
# 	Only 6 HLS scenes using lte 20% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 20% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 25% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				1
# 	Only 3 HLS scenes using lte 20% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 20% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				3
# 	Only 4 HLS scenes using lte 20% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				1
# 	Only 3 HLS scenes using lte 20% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 20% cloudcover for 2018-07-01T00:00:00Z-2018-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 20% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSS30_2.0):				1
# 	Only 2 HLS scenes using lte 30% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 20% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 30% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				2
# 	Only 5 HLS scenes using lte 25% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSS30_2.0):				4
# 	Only 6 HLS scenes using lte 25% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				3
# 	Only 6 HLS scenes using lte 25% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 25% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 25% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSS30_2.0):				1
# 	Only 4 HLS scenes using lte 25% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 25% cloudcover for 2018-07-01T00:00:00Z-2018-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				1
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 25% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 25% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 35% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSS30_2.0):				3
# 	Only 4 HLS scenes using lte 35% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSS30_2.0):				2
# 	Only 5 HLS scenes using lte 30% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 30% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				3
# 	Only 6 HLS scenes using lte 30% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 30% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				1
# 	Only 4 HLS scenes using lte 30% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 30% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				1
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 30% cloudcover for 2018-07-01T00:00:00Z-2018-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 30% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				3
# 	Only 6 HLS scenes using lte 35% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 40% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				4
# 	Only 6 HLS scenes using lte 35% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 30% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				3
# 	Only 4 HLS scenes using lte 40% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSS30_2.0):				5
# 	Only 8 HLS scenes using lte 35% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 35% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				1
# 	Only 4 HLS scenes using lte 35% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 35% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 35% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				6
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
# partial results (HLSL30_2.0):				3
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (10, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# HLS.L30.T21KXQ.2018197T133426.v2.0
# HLS.L30.T21KXP.2018197T133426.v2.0
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 45% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 40% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# HLS.L30.T21KXQ.2018204T134039.v2.0
# partial results (HLSS30_2.0):				4
# 	Only 6 HLS scenes using lte 40% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# HLS.L30.T21KXP.2018204T134039.v2.0
# HLS.S30.T21KXQ.2018184T135109.v2.0
# HLS.S30.T21KXQ.2018194T135109.v2.0
# HLS.S30.T21KXQ.2018199T135111.v2.0
# partial results (HLSL30_2.0):				3
# HLS.S30.T21KXP.2018199T135111.v2.0
# HLS.S30.T21KXP.2018204T135109.v2.0
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 35% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSS30_2.0):				5
# 	Only 8 HLS scenes using lte 40% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# HLS.S30.T21KXQ.2018204T135109.v2.0
#
# Total # of scenes for composite:		10
# Creating evi2 stack with HLS ...
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				3
# 	Only 4 HLS scenes using lte 45% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSS30_2.0):				5
# 	Only 8 HLS scenes using lte 40% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				3
# 	Only 6 HLS scenes using lte 40% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 40% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				5
# 	Only 7 HLS scenes using lte 45% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSL30_2.0):				1
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 40% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 45% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 40% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 50% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSS30_2.0):				5
# 	Only 8 HLS scenes using lte 45% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 45% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				3
# 	Only 4 HLS scenes using lte 50% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				5
# 	Only 8 HLS scenes using lte 45% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 45% cloudcover for 2019-03-01T00:00:00Z-2019-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				5
# 	Only 7 HLS scenes using lte 50% cloudcover for 2019-07-01T00:00:00Z-2019-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 45% cloudcover for 2019-09-01T00:00:00Z-2019-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 55% cloudcover for 2018-01-01T00:00:00Z-2018-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 55%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 50% cloudcover for 2018-03-01T00:00:00Z-2018-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 45% cloudcover for 2018-09-01T00:00:00Z-2018-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				5
# 	Only 8 HLS scenes using lte 50% cloudcover for 2019-11-01T00:00:00Z-2019-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 50% cloudcover for 2018-11-01T00:00:00Z-2018-11-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 55% cloudcover for 2019-05-01T00:00:00Z-2019-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 55%
# partial results (HLSL30_2.0):				4
# Traceback (most recent call last):
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 1002, in <module>
# partial results (HLSS30_2.0):				5
# 	Only 8 HLS scenes using lte 50% cloudcover for 2019-01-01T00:00:00Z-2019-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# Traceback (most recent call last):
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 1002, in <module>
# partial results (HLSL30_2.0):				2
# Traceback (most recent call last):
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 1002, in <module>
#     main()
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 772, in main
# partial results (HLSL30_2.0):				4
#     main()
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 772, in main
#     main()
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 772, in main
#     master_json = get_ms_data(args.in_tile_fn, args.in_tile_layer, args.in_tile_id_col, args.in_tile_num, args.output_dir, args.sat_api,
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/fetch_from_api.py", line 207, in get_ms_data
#     response_by_year = [query_stac(year, bbox, max_cloud, api, start_month_day, end_month_day, MS_product=ms_product,
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/fetch_from_api.py", line 150, in query_stac
#     results = search.get_all_items_as_dict()
# partial results (HLSL30_2.0):				3
# Traceback (most recent call last):
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 1002, in <module>
#     main()
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 772, in main
# Traceback (most recent call last):
#   File "/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py", line 1002, in <module>
#     main()
# ...
# 	Only 6 HLS scenes using lte 10% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				3
# 	Only 6 HLS scenes using lte 15% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				3
# 	Only 7 HLS scenes using lte 20% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				3
# 	Only 7 HLS scenes using lte 25% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95/tile_004/2018/HLS_4_07-01_07-31_2018_2018_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95/tile_004/2018/HLS_4_07-01_07-31_2018_2018_percentile95.0evi2.tif
#
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				3
# 	Only 7 HLS scenes using lte 30% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSL30_2.0):				4
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# partial results (HLSS30_2.0):				3
# 	Only 7 HLS scenes using lte 35% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2018-08-01T00:00:00Z 2018-08-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 40% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSS30_2.0):				5
# 	Only 7 HLS scenes using lte 5% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				5
# 	Only 7 HLS scenes using lte 10% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 45% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 15% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 50% cloudcover for 2018-06-01T00:00:00Z-2018-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 20% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSS30_2.0):				7
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	11
#
# Search complete.
#
# 11
# partial results (HLSL30_2.0):				2
# HLS.L30.T21KXQ.2018172T134024.v2.0
# HLS.L30.T21KXP.2018172T134024.v2.0
# HLS.L30.T21KXQ.2018181T133418.v2.0
# HLS.L30.T21KXP.2018181T133418.v2.0
# HLS.S30.T21KXP.2018159T135111.v2.0
# HLS.S30.T21KXQ.2018159T135111.v2.0
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 25% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# HLS.S30.T21KXQ.2018169T135111.v2.0
# HLS.S30.T21KXP.2018169T135111.v2.0
# HLS.S30.T21KXP.2018174T135109.v2.0
# HLS.S30.T21KXQ.2018174T135109.v2.0
# HLS.S30.T21KXQ.2018179T135111.v2.0
#
# Total # of scenes for composite:		11
# Creating evi2 stack with HLS ...
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 30% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 35% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 40% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 45% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# partial results (HLSL30_2.0):				3
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (11, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 50% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 55% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 55%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 60% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 60%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 65% cloudcover for 2018-08-01T00:00:00Z-2018-08-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 65%
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				6
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
# HLS.L30.T21KXQ.2018229T133442.v2.0
# HLS.L30.T21KXP.2018229T133442.v2.0
# HLS.L30.T21KXQ.2018236T134056.v2.0
# HLS.L30.T21KXP.2018236T134056.v2.0
# HLS.S30.T21KXQ.2018224T135109.v2.0
# HLS.S30.T21KXP.2018224T135109.v2.0
# HLS.S30.T21KXQ.2018229T135111.v2.0
# HLS.S30.T21KXP.2018229T135111.v2.0
# HLS.S30.T21KXP.2018239T135111.v2.0
# HLS.S30.T21KXQ.2018239T135111.v2.0
#
# Total # of scenes for composite:		10
# Creating evi2 stack with HLS ...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (10, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 5.04
# 		Standard Deviation: 2.59
# 		Minimum: -1.00
# 		Maximum: 9.00
# 		25th Percentile: 4.00
# 		50th Percentile (Median): 5.00
# 		75th Percentile: 7.00
# Count array min (0), max (10), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 5.08
# 		Standard Deviation: 2.14
# 		Minimum: -1.00
# 		Maximum: 9.00
# 		25th Percentile: 3.00
# 		50th Percentile (Median): 6.00
# 		75th Percentile: 7.00
# Count array min (0), max (10), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.16828929068150206
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 531107.63
# 		Standard Deviation: 1762986.74
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.15
# 		50th Percentile (Median): 0.29
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/93854e18-feb3-404d-92be-c88dbe14161e/93854e18-feb3-404d-92be-c88dbe14161e.tif)' mode='r'>
#   [------------------------------------]    0%Creating Green composite...
#   [####################################]  100%
# Adding overviews...
# Creating Red composite...
# Creating NIR composite...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95/tile_004/2018/HLS_4_06-01_06-30_2018_2018_percentile95.0evi2.tif
# Creating SWIR composite...
# Creating SWIR2 composite...
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95/tile_004/2018/HLS_4_06-01_06-30_2018_2018_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95/tile_004/2018/HLS_4_06-01_06-30_2018_2018_percentile95.0evi2.tif
#
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.11488862837045724
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 531316.03
# 		Standard Deviation: 1763290.08
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.13
# 		50th Percentile (Median): 0.26
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/7a4ed1fc-ae2b-4dae-9fe4-284e409b027d/7a4ed1fc-ae2b-4dae-9fe4-284e409b027d.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95/tile_004/2018/HLS_4_08-01_08-31_2018_2018_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95/tile_004/2018/HLS_4_08-01_08-31_2018_2018_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/monthly/br_af_grid30km_prj_evi2_p95/tile_004/2018/HLS_4_08-01_08-31_2018_2018_percentile95.0evi2.tif
#
# CPU times: user 332 ms, sys: 331 ms, total: 662 ms
# Wall time: 5min 48s

# %%
# # Plotting to check false composite to check
# fn = fn_list[0]
# fn
# rescaled_multiband_fn = fn.replace('.tif', '_rescaled_3band_temp.tif')
# plotlib.rescale_multiband_for_plot(fn, rescaled_multiband_fn, bandlist = [6,4,3], pct=[20,98], nodata=-9999.0) 

# fig,ax=plt.subplots(figsize=(10,10))
# with rasterio.open(rescaled_multiband_fn) as src:
#     #print(src.profile)
#     show(src.read(),transform=src.transform, ax=ax, title=os.path.basename(rescaled_multiband_fn))

# %%
### Notes

# Time to run 1 tile 1 year 12 processors

# %%
## CHECK ERRORS

## No output is created sometimes when runnning multiple jobs
