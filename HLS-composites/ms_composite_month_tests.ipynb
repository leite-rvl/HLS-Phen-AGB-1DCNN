# %%
import os

from pathlib import Path
from datetime import datetime
from calendar import monthrange

import fiona

import multiprocessing as mp

import geopandas as gpd

# %%
import sys
sys.path.append('/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib')
import plotlib
from mosaiclib import *

# %%
import rasterio
from rasterio.plot import show_hist, show
import numpy as np
import matplotlib.pyplot as plt

# %%
# Functions 
def wrapper_composite(params):

    FOCAL_TILE = params.get('FOCAL_TILE')
    SAT_API = params.get('SAT_API')
    MS_COMP_TYPE = params.get('MS_COMP_TYPE')
    YEAR = params.get('YEAR')
    MIN_N_FILT_RESULTS = params.get('MIN_N_FILT_RESULTS')
    SEASON_START = params.get('SEASON_START')
    SEASON_STOP = params.get('SEASON_STOP')
    # INDEX_FN = params.get('INDEX_FN')
    # INDEX_LYR = params.get('INDEX_LYR')
    
    STAT = params.get('STAT')
    STAT_PCT = params.get('STAT_PCT')
    TARGET_SPECTRAL = params.get('TARGET_SPECTRAL')

    INDEX_FN =  params.get('INDEX_FN') #'https://maap-ops-workspace.s3.amazonaws.com/shared/montesano/databank/boreal_tiles_v004.gpkg'
    INDEX_LYR = params.get('INDEX_LYR') # 'boreal_tiles_v004'
    
    YEAR_START, YEAR_STOP = (YEAR, YEAR)
    HLS_PRODUCT = params.get('HLS_PRODUCT') #HLS_PRODUCT = 'H30'
    MAX_CLOUDS = params.get('MAX_CLOUDS') #MAX_CLOUDS = 0

    OUTDIR = params.get('OUTDIR') #'/projects/my-private-bucket/tmp/mask_test_keep_snow'
    
    args = f"--in_tile_fn {INDEX_FN} \
        --in_tile_layer {INDEX_LYR} \
        --sat_api {SAT_API} \
        --tile_buffer_m 0 \
        --in_tile_num {FOCAL_TILE} \
        --output_dir {OUTDIR} \
        -sy {YEAR_START} -ey {YEAR_STOP} -smd {SEASON_START} -emd {SEASON_STOP} -mc {MAX_CLOUDS} \
        --composite_type {MS_COMP_TYPE} \
        --hls_product {HLS_PRODUCT} \
        --thresh_min_ndvi -1 \
        --min_n_filt_results {MIN_N_FILT_RESULTS} \
        --stat {STAT} \
        --stat_pct {STAT_PCT} \
        --target_spectral_index {TARGET_SPECTRAL}"
    args += " --do_indices"
    #args += " --search_only"
    # args += " --rangelims_red 0.01 0.1" # the default now effectively no limit [-1e9, 1e9]
    args += " --rangelims_red 0.01 1" # the default now effectively no limit [-1e9, 1e9]
    
    # cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite.py {args}'
    # cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_multip.py {args}'
    cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py {args}'
    #!echo $cmd
    # !eval $cmd

    fn = f'{OUTDIR}/{MS_COMP_TYPE}_{FOCAL_TILE}_{SEASON_START}_{SEASON_STOP}_{YEAR_START}_{YEAR_STOP}_{STAT}{TARGET_SPECTRAL}.tif'
    if STAT == 'percentile':
        fn = f'{OUTDIR}/{MS_COMP_TYPE}_{FOCAL_TILE}_{SEASON_START}_{SEASON_STOP}_{YEAR_START}_{YEAR_STOP}_{STAT}{STAT_PCT}{TARGET_SPECTRAL}.tif'
    #rescaled_multiband_fn = os.path.join(os.path.dirname(fn), os.path.basename(fn).replace('.tif','_rescaled_3band_temp.tif'))
    # plotlib.rescale_multiband_for_plot(fn, rescaled_multiband_fn, bandlist = [5,7,3], pct=[20,90], nodata=-9999.0) 

    return fn

# %%
# Set default parameters
SAT_API = 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'
MS_COMP_TYPE = 'HLS'
HLS_PRODUCT = 'H30'

# STAT = 'max'
STAT = 'percentile'

# TARGET_SPECTRAL = 'ndvi'
TARGET_SPECTRAL = 'evi2'
STAT_PCT = 95.0

MIN_N_FILT_RESULTS = 10
MAX_CLOUDS = 0 # Threshold of max clouds to start search, e.g. when set to 0 it starts at 0% of cloud cover and go up to 90% 

# INDEX_FN = '/projects/HLS/data/shp/atlantic_forest/tiles/ls_unit50km_utm23s.gpkg' # Needs a tile_num column with the index and be in a projected coordinate system

# INDEX_FN = '/projects/my-private-bucket/HLS/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg' 
# INDEX_LYR = 'br_af_grid90km_prj'

INDEX_FN = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg' 
INDEX_LYR = 'br_af_grid30km_prj'


# INDEX_FN = '/projects/HLS/data/shp/atlantic_forest/tiles/ls_unit100km_prj.gpkg' # Needs a tile_num column with the index and be in a projected coordinate system
# # Get first layer name
# layer_names = fiona.listlayers(INDEX_FN)
# # Get the first layer name
# first_layer_name = layer_names[0]
# INDEX_LYR = first_layer_name


BASE_OUTDIR = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_ndvi'

# %%
# INDEX_FN = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg' 
# INDEX_LYR = 'br_af_grid30km_prj'

# tiles_gpkg = gpd.read_file(INDEX_FN)

# %%
# import fiona
# with fiona.open(INDEX_FN) as src:
#     print(src.crs)
# import rasterio
# rast_path = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_12-01_12-31_2022_2022_percentile95.0evi2.tif'
# with rasterio.open(rast_path) as src:
#     print(src.crs)
# Out:
# EPSG:5880

# %% [markdown]
# ### Testing composite run

# %%
# Define list of tiles and years 
# test
tiles_gpkg = gpd.read_file(INDEX_FN)
tiles = tiles_gpkg["tile_num"].tolist()
# tiles

tiles_run = tiles[3:4]  
years = [2022] #[2018, 2024]

# All

# with fiona.open(INDEX_FN, layer=0) as src:
#     tiles = [feature["properties"]["tile_num"] for feature in src]
tiles_run

# %%
# Create dictionary of params
params = {
    'SAT_API': SAT_API,
    'HLS_PRODUCT': HLS_PRODUCT,
    'MS_COMP_TYPE': MS_COMP_TYPE,
    'MAX_CLOUDS': MAX_CLOUDS,
    'MIN_N_FILT_RESULTS': MIN_N_FILT_RESULTS,
    'STAT': STAT,
    'STAT_PCT': STAT_PCT,
    'TARGET_SPECTRAL': TARGET_SPECTRAL,
    'INDEX_FN': INDEX_FN,
    'INDEX_LYR': INDEX_LYR,
}

# %%
params

# %%
params.update({
                'FOCAL_TILE': 4,
                'YEAR': 2022,
                'SEASON_START': '01-01',
                'SEASON_STOP': '12-01',
                'OUTDIR': str(BASE_OUTDIR)
            })


fn = wrapper_composite(params)

# %%
params

# %%
# Check image bands
with rasterio.open(output_file) as src:
    # print(dir(src))
    # print(src.descriptions.index('count')) 
    print(src.descriptions) 
    
#     band_index = src.descriptions.index('count') + 1  # +1 because src.read is 1-based
    
#     # Read the count band as a numpy array
#     count_array = src.read(band_index)
    
# print(count_array.shape)
# print(count_array)   # if you want to see values
# import numpy
# print(numpy.unique(count_array))
# print(numpy.histogram(count_array))

# %%
## PLotting count
# fig,ax=plt.subplots(figsize=(10,10))
# with rasterio.open(output_file) as src:
#     count_band = src.read(src.descriptions.index('count')+1, masked=True)   # read the count band
#     # print(dir(plt))
#     # plt.legend()
#     # print(count_band)
#     img = show(count_band, transform=src.transform, ax=ax,
#          cmap="viridis") 
#     cbar = plt.colorbar(img.get_images()[0], ax=ax, label="Count values")

# %%
# import os
# os.system('gdalinfo -mm ' + output_file)

# %%
## Plotting true color
# with rasterio.open(output_file) as src:
#     print("Band descriptions:", src.descriptions)

#     # Define which bands correspond to R, G, B (adjust names/indexes as needed)
#     r_index = src.descriptions.index("Red") + 1
#     g_index = src.descriptions.index("Green") + 1
#     b_index = src.descriptions.index("Blue") + 1

#     # Read the 3 bands as masked arrays
#     rgb = src.read([r_index, g_index, b_index], masked=True)

#     # Reshape to H x W x 3 for plotting
#     rgb_img = rasterio.plot.reshape_as_image(rgb)

#     # Clip negative values to 0
#     rgb[rgb < 0] = 0

#     # Normalize to [0, 1] by percent stretch (optional: 2–98%)
#     p2, p98 = np.percentile(rgb.compressed(), (2, 98))
#     rgb = np.clip((rgb - p2) / (p98 - p2), 0, 1)

#     # Scale to [0, 255] and convert to uint8
#     rgb = (rgb * 255).astype(np.uint8)

#     # Reshape to H x W x 3 for plotting
#     rgb_img = rasterio.plot.reshape_as_image(rgb)

# fig, ax = plt.subplots(figsize=(10, 10))
# ax.imshow(rgb_img)
# ax.set_title("RGB Composite")
# ax.axis("off")
# plt.show()

# %%
## Plotting false composite
output_file = fn
rescaled_multiband_fn = output_file.replace('.tif', '_rescaled_3band_temp.tif')

# plotlib.rescale_multiband_for_plot(output_file, rescaled_multiband_fn, bandlist = [6,4,3], pct=[20,98], nodata=-9999.0) 
plotlib.rescale_multiband_for_plot(output_file, rescaled_multiband_fn, bandlist = [4,3,2], pct=[20,98], nodata=-9999.0) 


fig,ax=plt.subplots(figsize=(10,10))
with rasterio.open(rescaled_multiband_fn) as src:
    #print(src.profile)
    show(src.read(),transform=src.transform, ax=ax, title=os.path.basename(rescaled_multiband_fn))

# %%
# INDEX_FN = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg' 

# tiles_gpkg = gpd.read_file(INDEX_FN)

# %%
# tiles_gpkg.iloc[3].geometry.bounds

# %%
# tiles_gpkg

# %%
# for tile in tiles:
#     for year in years:
#         for month in range(2, 4):
#             # print(tile,year,month)
#             outdir = f'{BASE_OUTDIR}/tile_{tile}/{year}/{month:02d}'
#             print(outdir)

# %%
# BASE_OUTDIR

# %%
tiles_run

# %%
years

# %%
# %%time
for tile in tiles_run:
    for year in years:
        # for month in range(2, 4):
        for month in range(1, 13):
            start_day = f"{month:02d}-01"
            end_day = f"{month:02d}-{monthrange(year, month)[1]:02d}"

            # Compose output directory for this specific run
            outdir = f'{BASE_OUTDIR}/tile_{tile:03d}/{year}/{month:02d}'
            os.makedirs(outdir, exist_ok=True)

            params.update({
                'FOCAL_TILE': tile,
                'YEAR': year,
                'SEASON_START': start_day,
                'SEASON_STOP': end_day,
                'OUTDIR': str(outdir)
            })

            try:
                print(f"Running tile {tile}, year {year}, month {month:02d}")
                output_file = wrapper_composite(params)
                print(f"Output saved to: {output_file}")
            except Exception as e:
                print(f"Error processing tile {tile}, year {year}, month {month:02d}: {e}")

# %%
output_file = '/projects/my-private-bucket/HLS/data/tif/monthly_composites_evi/tile_001/2022/03/HLS_1_03-01_03-31_2022_2022_maxevi2.tif'

# %%
# rescaled_multiband_fn = output_file.replace('.tif', '_rescaled_3band_temp.tif')

# plotlib.rescale_multiband_for_plot(output_file, rescaled_multiband_fn, bandlist = [6,4,3], pct=[20,98], nodata=-9999.0) 


# fig,ax=plt.subplots(figsize=(10,10))
# with rasterio.open(rescaled_multiband_fn) as src:
#     #print(src.profile)
    # show(src.read(),transform=src.transform, ax=ax, title=os.path.basename(rescaled_multiband_fn))

# %% [markdown]
# ### Testing multiprocessing parallel

# %%
import multiprocessing as mp

num_cores = mp.cpu_count()
print(f"Number of CPU cores: {num_cores}")

import psutil

mem = psutil.virtual_memory()
print(f"Total memory: {mem.total / 1e9:.2f} GB")
print(f"Available memory: {mem.available / 1e9:.2f} GB")
# Out:
# Number of CPU cores: 32
# Total memory: 267.33 GB
# Available memory: 256.80 GB

# %%
params = {
    'SAT_API': SAT_API,
    'HLS_PRODUCT': HLS_PRODUCT,
    'MS_COMP_TYPE': MS_COMP_TYPE,
    'MAX_CLOUDS': MAX_CLOUDS,
    'MIN_N_FILT_RESULTS': MIN_N_FILT_RESULTS,
    'STAT': STAT,
    'STAT_PCT': STAT_PCT,
    'TARGET_SPECTRAL': TARGET_SPECTRAL,
    'INDEX_FN': INDEX_FN,
    'INDEX_LYR': INDEX_LYR,
}

# %%
INDEX_FN = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg'  # Needs a tile_num column with the index and be in a projected coordinate system
# Get first layer name
layer_names = fiona.listlayers(INDEX_FN)
# Get the first layer name
first_layer_name = layer_names[0]
INDEX_LYR = first_layer_name

BASE_OUTDIR = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2'
# INDEX_LYR

# %%
# tiles = [1]#[5,10]  
years = [2022]

# All
with fiona.open(INDEX_FN, layer=0) as src:
    tiles = [feature["properties"]["tile_num"] for feature in src]
    
tiles_gpkg = gpd.read_file(INDEX_FN)
tiles = tiles_gpkg["tile_num"].tolist()
# # tiles

# %%
len(tiles)
# Out:
# 1561

# %%
# TEST
# tiles_run = tiles[0:1]
# tiles_run
# CPU times: user 560 ms, sys: 555 ms, total: 1.11 s
# Wall time: 5min 41s
# Only month 9 10 11 with valid results 

# Run 1
tiles_run = tiles[3:4]
tiles_run
# Out:
# [4]

# %% [markdown]
# ## Running all tiles 1 year multiprocess

# %%
# Printing output directory

outdirs = []

for tile in tiles_run: 
    for year in years:
        for month in range(1, 13):
            start_day = f"{month:02d}-01"
            end_day = f"{month:02d}-{monthrange(year, month)[1]:02d}"
            
            outdir = f'{BASE_OUTDIR}/tile_{tile:03d}/{year}/{month:02d}'
            outdirs.append(outdir)

outdirs[-1]
# Out:
# '/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/12'

# %%
import copy

# %%
years = [2022]
# years = [2018,2019,2020,2021]
# years = [2015,2016,2017]

# type(years)

# %%
# %%time
# Create parameter list and create output directories
params_list = []
for tile in tiles_run: 
    for year in years:
        # for month in range(2, 4):
        for month in range(1, 13):
            start_day = f"{month:02d}-01"
            end_day = f"{month:02d}-{monthrange(year, month)[1]:02d}"
    
            # output directory for specific run
            # outdir = f'{BASE_OUTDIR}/tile_{tile:03d}/{year}/{month:02d}'
            outdir = f'{BASE_OUTDIR}/tile_{tile:03d}/{year}/'
            
            os.makedirs(outdir, exist_ok=True)
    
            run_params = copy.deepcopy(params)
            run_params.update({
                'FOCAL_TILE': tile,
                'YEAR': year,
                'SEASON_START': start_day,
                'SEASON_STOP': end_day,
                'OUTDIR': str(outdir)
            })
    
            params_list.append(run_params)
# Out:
# CPU times: user 2.03 ms, sys: 94 µs, total: 2.12 ms
# Wall time: 161 ms

# %%
# n_process = mp.cpu_count() - 1
# n_process

# %%
len(params_list)
# Out:
# 12

# %%
# %%time
# mp.cpu_count() - 1
with mp.Pool(processes= 5) as pool:
    fn_list = pool.map(wrapper_composite, params_list)
# Out:
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-02-01T00:00:00Z 2022-02-28T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-05-01T00:00:00Z 2022-05-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-03-01T00:00:00Z 2022-03-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-04-01T00:00:00Z 2022-04-30T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-01-01T00:00:00Z 2022-01-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				6
# partial results (HLSL30_2.0):				0
# partial results (HLSL30_2.0):				0
# partial results (HLSL30_2.0):				4
# partial results (HLSS30_2.0):				0
# 	Only 0 HLS scenes using lte 5% cloudcover for 2022-01-01T00:00:00Z-2022-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				5
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	11
#
# Search complete.
#
# 11
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				2
# 	Only 2 HLS scenes using lte 5% cloudcover for 2022-04-01T00:00:00Z-2022-04-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				1
# 	Only 5 HLS scenes using lte 5% cloudcover for 2022-03-01T00:00:00Z-2022-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 5% cloudcover for 2022-05-01T00:00:00Z-2022-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# HLS.L30.T21KXQ.2022040T133530.v2.0
# HLS.L30.T21KXP.2022040T133530.v2.0
# HLS.L30.T21KXQ.2022047T134137.v2.0
# HLS.L30.T21KXP.2022047T134137.v2.0
# HLS.L30.T21KXP.2022048T133518.v2.0
# HLS.L30.T21KXP.2022055T134128.v2.0
# HLS.S30.T21KXQ.2022038T135111.v2.0
# HLS.S30.T21KXP.2022043T135109.v2.0
# HLS.S30.T21KXQ.2022048T135111.v2.0
# HLS.S30.T21KXP.2022048T135111.v2.0
# HLS.S30.T21KXP.2022058T135121.v2.0
# partial results (HLSL30_2.0):				4
#
# Total # of scenes for composite:		11
# Creating evi2 stack with HLS ...
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 10% cloudcover for 2022-01-01T00:00:00Z-2022-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				7
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 10% cloudcover for 2022-04-01T00:00:00Z-2022-04-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 10% cloudcover for 2022-05-01T00:00:00Z-2022-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 15% cloudcover for 2022-01-01T00:00:00Z-2022-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (11, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# partial results (HLSS30_2.0):				2
# 	Only 9 HLS scenes using lte 10% cloudcover for 2022-03-01T00:00:00Z-2022-03-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				7
# partial results (HLSS30_2.0):				3
# 	Only 5 HLS scenes using lte 20% cloudcover for 2022-01-01T00:00:00Z-2022-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSS30_2.0):				3
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
# HLS.L30.T21KXQ.2022064T133515.v2.0
# HLS.L30.T21KXP.2022064T133515.v2.0
# HLS.L30.T21KXP.2022080T133507.v2.0
# HLS.L30.T21KXQ.2022080T133507.v2.0
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 15% cloudcover for 2022-05-01T00:00:00Z-2022-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# HLS.L30.T21KXP.2022087T134111.v2.0
# partial results (HLSS30_2.0):				4
# 	Only 6 HLS scenes using lte 15% cloudcover for 2022-04-01T00:00:00Z-2022-04-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# HLS.L30.T21KXQ.2022087T134111.v2.0
# HLS.L30.T21KXP.2022088T133512.v2.0
# HLS.S30.T21KXQ.2022068T135121.v2.0
# HLS.S30.T21KXP.2022068T135121.v2.0
# HLS.S30.T21KXP.2022073T135109.v2.0
#
# Total # of scenes for composite:		10
# Creating evi2 stack with HLS ...
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				3
# 	Only 6 HLS scenes using lte 25% cloudcover for 2022-01-01T00:00:00Z-2022-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 20% cloudcover for 2022-05-01T00:00:00Z-2022-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSS30_2.0):				5
# 	Only 7 HLS scenes using lte 20% cloudcover for 2022-04-01T00:00:00Z-2022-04-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 25% cloudcover for 2022-04-01T00:00:00Z-2022-04-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 30% cloudcover for 2022-01-01T00:00:00Z-2022-01-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 25% cloudcover for 2022-05-01T00:00:00Z-2022-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				4
# partial results (HLSL30_2.0):				4
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (10, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 30% cloudcover for 2022-04-01T00:00:00Z-2022-04-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 30% cloudcover for 2022-05-01T00:00:00Z-2022-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSS30_2.0):				6
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
# partial results (HLSL30_2.0):				3
# partial results (HLSL30_2.0):				4
# HLS.L30.T21KXQ.2022023T134136.v2.0
# HLS.L30.T21KXP.2022023T134136.v2.0
# HLS.L30.T21KXP.2022024T133531.v2.0
# HLS.L30.T21KXP.2022031T134142.v2.0
# HLS.S30.T21KXQ.2022008T135111.v2.0
# HLS.S30.T21KXP.2022008T135111.v2.0
# HLS.S30.T21KXQ.2022018T135111.v2.0
# HLS.S30.T21KXP.2022018T135111.v2.0
# HLS.S30.T21KXQ.2022023T135109.v2.0
# HLS.S30.T21KXP.2022023T135109.v2.0
#
# Total # of scenes for composite:		10
# Creating evi2 stack with HLS ...
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 35% cloudcover for 2022-05-01T00:00:00Z-2022-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSS30_2.0):				6
# 	Only 9 HLS scenes using lte 35% cloudcover for 2022-04-01T00:00:00Z-2022-04-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSL30_2.0):				4
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (10, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# partial results (HLSS30_2.0):				6
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
# HLS.L30.T21KXQ.2022112T133504.v2.0
# HLS.L30.T21KXQ.2022119T134112.v2.0
# HLS.L30.T21KXP.2022120T133500.v2.0
# HLS.L30.T21KXQ.2022120T133500.v2.0
# HLS.S30.T21KXQ.2022093T135109.v2.0
# HLS.S30.T21KXP.2022093T135109.v2.0
# HLS.S30.T21KXQ.2022108T135121.v2.0
# HLS.S30.T21KXP.2022108T135121.v2.0
# partial results (HLSL30_2.0):				4
# HLS.S30.T21KXQ.2022118T135121.v2.0
# HLS.S30.T21KXP.2022118T135121.v2.0
#
# Total # of scenes for composite:		10
# Creating evi2 stack with HLS ...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (10, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# partial results (HLSS30_2.0):				5
# 	Only 9 HLS scenes using lte 40% cloudcover for 2022-05-01T00:00:00Z-2022-05-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSL30_2.0):				5
# partial results (HLSS30_2.0):				5
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
# HLS.L30.T21KXP.2022127T134107.v2.0
# HLS.L30.T21KXQ.2022127T134107.v2.0
# HLS.L30.T21KXP.2022143T134057.v2.0
# HLS.L30.T21KXQ.2022144T133511.v2.0
# HLS.L30.T21KXP.2022144T133511.v2.0
# HLS.S30.T21KXQ.2022128T135121.v2.0
# HLS.S30.T21KXP.2022128T135121.v2.0
# HLS.S30.T21KXQ.2022133T135109.v2.0
# HLS.S30.T21KXP.2022133T135109.v2.0
# HLS.S30.T21KXP.2022143T135109.v2.0
#
# Total # of scenes for composite:		10
# Creating evi2 stack with HLS ...
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 6.80
# 		Standard Deviation: 2.63
# 		Minimum: -1.00
# 		Maximum: 10.00
# 		25th Percentile: 5.00
# 		50th Percentile (Median): 7.00
# 		75th Percentile: 10.00
# Count array min (0), max (10), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (10, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 5.66
# 		Standard Deviation: 1.80
# 		Minimum: -1.00
# 		Maximum: 9.00
# 		25th Percentile: 4.00
# 		50th Percentile (Median): 5.00
# 		75th Percentile: 7.00
# Count array min (0), max (9), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# Creating Green composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.28735632183908044
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 531579.75
# 		Standard Deviation: 1763692.54
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.15
# 		50th Percentile (Median): 0.31
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/98878198-7019-42e9-ac33-33d98d8b22fc/98878198-7019-42e9-ac33-33d98d8b22fc.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Creating Red composite...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_02-01_02-28_2022_2022_percentile95.0evi2.tif
# Creating NIR composite...
# Creating SWIR composite...
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 4.50
# 		Standard Deviation: 2.10
# 		Minimum: -1.00
# 		Maximum: 9.00
# 		25th Percentile: 4.00
# 		50th Percentile (Median): 5.00
# 		75th Percentile: 6.00
# Count array min (0), max (9), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating SWIR2 composite...
# Creating Green composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_02-01_02-28_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_02-01_02-28_2022_2022_percentile95.0evi2.tif
#
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.15959004392386536
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 531234.31
# Creating Red composite...
# 		Standard Deviation: 1763180.19
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.16
# 		50th Percentile (Median): 0.34
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/11284169-8257-4648-9fb3-3d1aae9e336f/11284169-8257-4648-9fb3-3d1aae9e336f.tif)' mode='r'>
#   [#############-----------------------]   37%
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#   [##################------------------]   50%in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
#   [###########################---------]   75%  00:00:00Creating NIR composite...
#   [#############################-------]   81%  00:00:00Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-06-01T00:00:00Z 2022-06-30T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
#   [####################################]  100%
# Adding overviews...
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				5
# 	Only 5 HLS scenes using lte 5% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				0
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_03-01_03-31_2022_2022_percentile95.0evi2.tif
# Creating SWIR composite...
# partial results (HLSS30_2.0):				6
# 	Only 6 HLS scenes using lte 10% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				6
# 	Only 6 HLS scenes using lte 15% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# partial results (HLSL30_2.0):				0
# Creating SWIR2 composite...
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 6.43
# 		Standard Deviation: 2.26
# 		Minimum: -1.00
# 		Maximum: 9.00
# 		25th Percentile: 5.00
# 		50th Percentile (Median): 7.00
# 		75th Percentile: 8.00
# Count array min (0), max (9), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# partial results (HLSS30_2.0):				6
# 	Only 6 HLS scenes using lte 20% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				6
# 	Only 6 HLS scenes using lte 25% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				0
# Creating Green composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# partial results (HLSS30_2.0):				6
# 	Only 6 HLS scenes using lte 30% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_03-01_03-31_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_03-01_03-31_2022_2022_percentile95.0evi2.tif
#
# partial results (HLSL30_2.0):				1
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.29113924050632906
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 531341.76
# 		Standard Deviation: 1763344.27
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.15
# 		50th Percentile (Median): 0.31
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/8486c4eb-9ca5-4266-bce1-f78f69b5bd1b/8486c4eb-9ca5-4266-bce1-f78f69b5bd1b.tif)' mode='r'>
#   [#############-----------------------]   37%Creating Red composite...
#   [##################------------------]   50%partial results (HLSS30_2.0):				6
# 	Only 7 HLS scenes using lte 35% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
#   [######################--------------]   62%  00:00:00
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#   [########################------------]   68%  00:00:00in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
#   [###########################---------]   75%  00:00:00bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
#   [####################################]  100%
# Adding overviews...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-07-01T00:00:00Z 2022-07-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				2
# Creating NIR composite...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_01-01_01-31_2022_2022_percentile95.0evi2.tif
# partial results (HLSL30_2.0):				6
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 40% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSS30_2.0):				3
# 	Only 9 HLS scenes using lte 5% cloudcover for 2022-07-01T00:00:00Z-2022-07-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# Creating SWIR composite...
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				8
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 45% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
# Creating SWIR2 composite...
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_01-01_01-31_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_01-01_01-31_2022_2022_percentile95.0evi2.tif
#
# Creating Julian Date composite...
# partial results (HLSL30_2.0):				2
# Creating Year Date composite...
# Creating Fmask composite...
# partial results (HLSS30_2.0):				5
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	13
#
# Search complete.
#
# 13
# HLS.L30.T21KXQ.2022183T134141.v2.0
# HLS.L30.T21KXP.2022183T134141.v2.0
# HLS.L30.T21KXQ.2022184T133507.v2.0
# HLS.L30.T21KXP.2022184T133507.v2.0
# HLS.L30.T21KXP.2022200T133508.v2.0
# HLS.L30.T21KXQ.2022200T133508.v2.0
# HLS.L30.T21KXQ.2022207T134125.v2.0
# HLS.L30.T21KXP.2022207T134125.v2.0
# HLS.S30.T21KXQ.2022183T134709.v2.0
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.022480058013052973
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# HLS.S30.T21KXP.2022183T134709.v2.0
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# HLS.S30.T21KXQ.2022203T134709.v2.0
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# HLS.S30.T21KXP.2022203T134709.v2.0
# HLS.S30.T21KXQ.2022208T134711.v2.0
# 		Mean: 530466.36
#
# Total # of scenes for composite:		13
# 		Standard Deviation: 1762043.64
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# Creating evi2 stack with HLS ...
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 50% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# 		25th Percentile: 0.16
# 		50th Percentile (Median): 0.35
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/01fe93fb-0540-410a-8d14-23ac1320cfd6/01fe93fb-0540-410a-8d14-23ac1320cfd6.tif)' mode='r'>
#   [####--------------------------------]   12%
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
#   [#########---------------------------]   25%in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# partial results (HLSL30_2.0):				2
#   [######################--------------]   62%  00:00:00Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-08-01T00:00:00Z 2022-08-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
#   [####################################]  100%
# Adding overviews...
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 55% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 55%
# partial results (HLSL30_2.0):				6
# partial results (HLSL30_2.0):				2
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_04-01_04-30_2022_2022_percentile95.0evi2.tif
# partial results (HLSS30_2.0):				6
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	12
#
# Search complete.
#
# 12
# HLS.L30.T21KXP.2022224T133546.v2.0
# HLS.L30.T21KXQ.2022224T133546.v2.0
# HLS.L30.T21KXQ.2022232T133528.v2.0
# HLS.L30.T21KXP.2022232T133528.v2.0
# HLS.L30.T21KXP.2022239T134140.v2.0
# HLS.L30.T21KXQ.2022239T134140.v2.0
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 60% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 60%
# HLS.S30.T21KXQ.2022233T134709.v2.0
# HLS.S30.T21KXP.2022233T134709.v2.0
# HLS.S30.T21KXQ.2022238T134721.v2.0
# HLS.S30.T21KXP.2022238T134721.v2.0
# HLS.S30.T21KXQ.2022243T134709.v2.0
# HLS.S30.T21KXP.2022243T134709.v2.0
#
# Total # of scenes for composite:		12
# Creating evi2 stack with HLS ...
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 3.20
# 		Standard Deviation: 3.13
# 		Minimum: -1.00
# 		Maximum: 9.00
# 		25th Percentile: 0.00
# 		50th Percentile (Median): 2.00
# 		75th Percentile: 6.00
# Count array min (0), max (9), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# partial results (HLSL30_2.0):				2
# Creating Green composite...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (13, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_04-01_04-30_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_04-01_04-30_2022_2022_percentile95.0evi2.tif
#
# Creating Red composite...
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 65% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 65%
# Creating NIR composite...
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (12, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# Creating SWIR composite...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-09-01T00:00:00Z 2022-09-30T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				0
# 	Only 0 HLS scenes using lte 5% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				0
# Creating SWIR2 composite...
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 70% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 70%
# partial results (HLSS30_2.0):				1
# 	Only 1 HLS scenes using lte 10% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				6
# 	Only 8 HLS scenes using lte 75% cloudcover for 2022-06-01T00:00:00Z-2022-06-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 75%
# partial results (HLSS30_2.0):				1
# 	Only 1 HLS scenes using lte 15% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# partial results (HLSL30_2.0):				0
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -10.000000000000002
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# partial results (HLSL30_2.0):				4
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 531178.05
# 		Standard Deviation: 1763093.48
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.16
# 		50th Percentile (Median): 0.34
# partial results (HLSS30_2.0):				1
# 	Only 1 HLS scenes using lte 20% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/3089511c-a6ab-48d6-bfdd-d34c9ed77214/3089511c-a6ab-48d6-bfdd-d34c9ed77214.tif)' mode='r'>
#   [------------------------------------]    0%partial results (HLSS30_2.0):				6
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
#   [##----------------------------------]    6%partial results (HLSL30_2.0):				0
#   [####--------------------------------]   12%HLS.L30.T21KXP.2022167T134137.v2.0
#   [#########---------------------------]   25%HLS.L30.T21KXQ.2022167T134137.v2.0
# HLS.L30.T21KXQ.2022175T134119.v2.0
#   [#############-----------------------]   37%HLS.L30.T21KXQ.2022176T133529.v2.0
# HLS.S30.T21KXQ.2022163T134709.v2.0
#   [##################------------------]   50%HLS.S30.T21KXP.2022163T134709.v2.0
# HLS.S30.T21KXQ.2022173T134709.v2.0
#   [######################--------------]   62%  00:00:00HLS.S30.T21KXP.2022173T134709.v2.0
# HLS.S30.T21KXQ.2022178T134721.v2.0
#   [###########################---------]   75%  00:00:00HLS.S30.T21KXP.2022178T134721.v2.0
#   [#############################-------]   81%  00:00:00
# Total # of scenes for composite:		10
#   [###############################-----]   87%  00:00:00Creating evi2 stack with HLS ...
#   [####################################]  100%
# Adding overviews...
# partial results (HLSS30_2.0):				1
# 	Only 1 HLS scenes using lte 25% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 25%
# partial results (HLSL30_2.0):				0
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_05-01_05-31_2022_2022_percentile95.0evi2.tif
# partial results (HLSS30_2.0):				1
# 	Only 1 HLS scenes using lte 30% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 30%
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				1
# 	Only 1 HLS scenes using lte 35% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 35%
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				1
# 	Only 1 HLS scenes using lte 40% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 40%
# partial results (HLSL30_2.0):				0
# partial results (HLSS30_2.0):				1
# 	Only 1 HLS scenes using lte 45% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 45%
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (10, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# partial results (HLSL30_2.0):				1
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_05-01_05-31_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_05-01_05-31_2022_2022_percentile95.0evi2.tif
#
# partial results (HLSS30_2.0):				2
# 	Only 3 HLS scenes using lte 50% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 50%
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				2
# 	Only 3 HLS scenes using lte 55% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 55%
# partial results (HLSL30_2.0):				1
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid30km_prj.gpkg
# Tile number:		 4
# Output res (m):		 30
# in_bbox:		 [4839419.049164498, 7374073.29125729, 4869419.049164498, 7404073.29125729]
# bbox 4326:		 [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		1000 x 1000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-55.574889898123715, -23.729593329414808, -55.278057362641555, -23.456105892179057]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-10-01T00:00:00Z 2022-10-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSS30_2.0):				2
# 	Only 3 HLS scenes using lte 60% cloudcover for 2022-09-01T00:00:00Z-2022-09-30T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 60%
# partial results (HLSL30_2.0):				2
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				2
# 	Only 4 HLS scenes using lte 5% cloudcover for 2022-10-01T00:00:00Z-2022-10-31T23:59:59Z for bbox.
# ...
# HLS.L30.T21KXP.2022311T134204.v2.0
# HLS.L30.T21KXQ.2022312T133542.v2.0
# HLS.L30.T21KXP.2022312T133542.v2.0
# HLS.L30.T21KXP.2022319T134154.v2.0
# HLS.L30.T21KXQ.2022319T134154.v2.0
# HLS.L30.T21KXP.2022328T133542.v2.0
# HLS.L30.T21KXQ.2022328T133542.v2.0
# HLS.S30.T21KXQ.2022308T134711.v2.0
# HLS.S30.T21KXP.2022308T134711.v2.0
# HLS.S30.T21KXP.2022313T134709.v2.0
# HLS.S30.T21KXQ.2022323T134709.v2.0
# HLS.S30.T21KXP.2022323T134709.v2.0
# HLS.S30.T21KXQ.2022328T134701.v2.0
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-12-01T00:00:00Z 2022-12-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# HLS.S30.T21KXP.2022328T134701.v2.0
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_06-01_06-30_2022_2022_percentile95.0evi2.tif
#
# Total # of scenes for composite:		15
# Creating evi2 stack with HLS ...
# partial results (HLSL30_2.0):				1
# partial results (HLSS30_2.0):				3
# 	Only 4 HLS scenes using lte 5% cloudcover for 2022-12-01T00:00:00Z-2022-12-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 5%
# partial results (HLSL30_2.0):				2
# partial results (HLSS30_2.0):				4
# 	Only 6 HLS scenes using lte 10% cloudcover for 2022-12-01T00:00:00Z-2022-12-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 10%
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 4.37
# 		Standard Deviation: 0.85
# 		Minimum: -1.00
# 		Maximum: 6.00
# 		25th Percentile: 4.00
# 		50th Percentile (Median): 4.00
# 		75th Percentile: 5.00
# Count array min (0), max (4), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_06-01_06-30_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_06-01_06-30_2022_2022_percentile95.0evi2.tif
#
# partial results (HLSL30_2.0):				3
# partial results (HLSS30_2.0):				4
# 	Only 7 HLS scenes using lte 15% cloudcover for 2022-12-01T00:00:00Z-2022-12-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 15%
# Creating Green composite...
# partial results (HLSL30_2.0):				4
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (15, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# Creating Red composite...
# partial results (HLSS30_2.0):				4
# 	Only 8 HLS scenes using lte 20% cloudcover for 2022-12-01T00:00:00Z-2022-12-31T23:59:59Z for bbox.
# 	Increase max_cloud by 5% until you get >= 10 scenes to composite or the 90% cloudcover limit is reached.
# Max cloudcover threshold now at: 20%
# Creating NIR composite...
# partial results (HLSL30_2.0):				6
# Creating SWIR composite...
# partial results (HLSS30_2.0):				4
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	10
#
# Search complete.
#
# 10
# HLS.L30.T21KXP.2022335T134150.v2.0
# HLS.L30.T21KXQ.2022336T133549.v2.0
# HLS.L30.T21KXP.2022336T133549.v2.0
# HLS.L30.T21KXQ.2022351T134152.v2.0
# HLS.L30.T21KXP.2022351T134152.v2.0
# HLS.L30.T21KXP.2022360T133540.v2.0
# HLS.S30.T21KXQ.2022348T134701.v2.0
# HLS.S30.T21KXP.2022348T134701.v2.0
# HLS.S30.T21KXQ.2022363T134709.v2.0
# HLS.S30.T21KXP.2022363T134709.v2.0
#
# Total # of scenes for composite:		10
# Creating evi2 stack with HLS ...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.01188332733165285
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 526590.29
# 		Standard Deviation: 1756297.37
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.13
# 		50th Percentile (Median): 0.28
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/04dc610e-4357-4ef3-a712-34190421e80b/04dc610e-4357-4ef3-a712-34190421e80b.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (10, 1000, 1000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_09-01_09-30_2022_2022_percentile95.0evi2.tif
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 6.88
# 		Standard Deviation: 2.62
# 		Minimum: -1.00
# 		Maximum: 9.00
# 		25th Percentile: 5.00
# 		50th Percentile (Median): 8.00
# 		75th Percentile: 9.00
# Count array min (0), max (8), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_09-01_09-30_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_09-01_09-30_2022_2022_percentile95.0evi2.tif
#
# Creating Green composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.24634146341463412
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 530761.49
# 		Standard Deviation: 1762464.96
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.16
# 		50th Percentile (Median): 0.34
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/3ac17ed3-cb4c-4d90-836a-97cec931ba17/3ac17ed3-cb4c-4d90-836a-97cec931ba17.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_10-01_10-31_2022_2022_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_10-01_10-31_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_10-01_10-31_2022_2022_percentile95.0evi2.tif
#
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 11.71
# 		Standard Deviation: 3.47
# 		Minimum: -1.00
# 		Maximum: 14.00
# 		25th Percentile: 11.00
# 		50th Percentile (Median): 13.00
# 		75th Percentile: 14.00
# Count array min (0), max (15), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
# <class 'numpy.ndarray'>
# (1000, 1000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (1000, 1000)
# 		Valid Pixel Count: 1000000
# 		Mean: 6.24
# 		Standard Deviation: 2.46
# 		Minimum: -1.00
# 		Maximum: 9.00
# 		25th Percentile: 6.00
# 		50th Percentile (Median): 7.00
# 		75th Percentile: 8.00
# Count array min (0), max (9), and shape ((1000, 1000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating NIR composite...
# Creating Green composite...
# Creating SWIR composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR2 composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.31118881118881114
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
# Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 531655.43
# 		Standard Deviation: 1763782.63
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
# 		25th Percentile: 0.17
# 		50th Percentile (Median): 0.36
# 		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/0864159b-ab7a-447f-8497-0420631291b1/0864159b-ab7a-447f-8497-0420631291b1.tif)' mode='r'>
#   [------------------------------------]    0%	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.4842767295597484
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
#   [##----------------------------------]    6%Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 1000, 1000)
#   [####--------------------------------]   12%Stack shape post-mask:		(23, 1000, 1000)
# 	Printing array stats: (23, 1000, 1000)
# 		Valid Pixel Count: 23000000
# 		Mean: 531197.10
#   [#########---------------------------]   25%		Standard Deviation: 1763103.80
# 		Minimum: -9999.00
# 		Maximum: 7404058.50
#   [##################------------------]   50%		25th Percentile: 0.18
#   [######################--------------]   62%  00:00:00		50th Percentile (Median): 0.37
#   [###########################---------]   75%  00:00:00		75th Percentile: 1.00
# Shape of input:			 (23, 1000, 1000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,1000,1000)
# Output resolution:		 (30, 30)
#   [###############################-----]   87%  00:00:00Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,1000,1000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/21eaa00b-abec-410f-a072-f9c106416a51/21eaa00b-abec-410f-a072-f9c106416a51.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_11-01_11-30_2022_2022_percentile95.0evi2.tif
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_12-01_12-31_2022_2022_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_11-01_11-30_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_11-01_11-30_2022_2022_percentile95.0evi2.tif
#
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_12-01_12-31_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/tmp/tests_evi2_p95_2/tile_004/2022/HLS_4_12-01_12-31_2022_2022_percentile95.0evi2.tif
#
# CPU times: user 350 ms, sys: 303 ms, total: 652 ms
# Wall time: 8min 11s

# %%
fn = fn_list[0]
fn

# %%
rescaled_multiband_fn = fn.replace('.tif', '_rescaled_3band_temp.tif')

plotlib.rescale_multiband_for_plot(fn, rescaled_multiband_fn, bandlist = [6,4,3], pct=[20,98], nodata=-9999.0) 


fig,ax=plt.subplots(figsize=(10,10))
with rasterio.open(rescaled_multiband_fn) as src:
    #print(src.profile)
    show(src.read(),transform=src.transform, ax=ax, title=os.path.basename(rescaled_multiband_fn))

# %%
### Notes

# Time to run 1 tile 1 year
# CPU times: user 487 ms, sys: 411 ms, total: 898 ms
# Wall time: 4min 15s

# Time to run 1 tile 2018 - 2022
# CPU times: user 1.93 s, sys: 1.7 s, total: 3.62 s
# Wall time: 18min 22s

# %%
## CHECK ERRORS
