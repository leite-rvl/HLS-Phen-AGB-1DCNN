# %%
import os

from pathlib import Path
from datetime import datetime
from calendar import monthrange

import fiona

import multiprocessing as mp

import geopandas as gpd

import copy

# %%
import sys
sys.path.append('/projects/my-private-bucket/code-git-shared/icesat2_boreal/lib')
import plotlib
from mosaiclib import *

# %%
import rasterio
from rasterio.plot import show_hist, show
import numpy as np
import matplotlib.pyplot as plt

# %%
import multiprocessing as mp

num_cores = mp.cpu_count()
print(f"Number of CPU cores: {num_cores}")

import psutil

mem = psutil.virtual_memory()
print(f"Total memory: {mem.total / 1e9:.2f} GB")
print(f"Available memory: {mem.available / 1e9:.2f} GB")
# Out:
# Number of CPU cores: 32
# Total memory: 267.33 GB
# Available memory: 193.47 GB

# %%
# Functions 
def wrapper_composite(params):

    FOCAL_TILE = params.get('FOCAL_TILE')
    SAT_API = params.get('SAT_API')
    MS_COMP_TYPE = params.get('MS_COMP_TYPE')
    YEAR = params.get('YEAR')
    MIN_N_FILT_RESULTS = params.get('MIN_N_FILT_RESULTS')
    SEASON_START = params.get('SEASON_START')
    SEASON_STOP = params.get('SEASON_STOP')
    # INDEX_FN = params.get('INDEX_FN')
    # INDEX_LYR = params.get('INDEX_LYR')
    
    STAT = params.get('STAT')
    STAT_PCT = params.get('STAT_PCT')
    TARGET_SPECTRAL = params.get('TARGET_SPECTRAL')

    INDEX_FN =  params.get('INDEX_FN') #'https://maap-ops-workspace.s3.amazonaws.com/shared/montesano/databank/boreal_tiles_v004.gpkg'
    INDEX_LYR = params.get('INDEX_LYR') # 'boreal_tiles_v004'
    
    YEAR_START, YEAR_STOP = (YEAR, YEAR)
    HLS_PRODUCT = params.get('HLS_PRODUCT') #HLS_PRODUCT = 'H30'
    MAX_CLOUDS = params.get('MAX_CLOUDS') #MAX_CLOUDS = 0

    OUTDIR = params.get('OUTDIR') #'/projects/my-private-bucket/tmp/mask_test_keep_snow'
    
    args = f"--in_tile_fn {INDEX_FN} \
        --in_tile_layer {INDEX_LYR} \
        --sat_api {SAT_API} \
        --tile_buffer_m 0 \
        --in_tile_num {FOCAL_TILE} \
        --output_dir {OUTDIR} \
        -sy {YEAR_START} -ey {YEAR_STOP} -smd {SEASON_START} -emd {SEASON_STOP} -mc {MAX_CLOUDS} \
        --composite_type {MS_COMP_TYPE} \
        --hls_product {HLS_PRODUCT} \
        --thresh_min_ndvi -1 \
        --min_n_filt_results {MIN_N_FILT_RESULTS} \
        --stat {STAT} \
        --stat_pct {STAT_PCT} \
        --target_spectral_index {TARGET_SPECTRAL}"
    args += " --do_indices"
    #args += " --search_only"
    # args += " --rangelims_red 0.01 0.1" # the default now effectively no limit [-1e9, 1e9]
    args += " --rangelims_red 0.01 1" # the default now effectively no limit [-1e9, 1e9]
    
    # cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite.py {args}'
    # cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_multip.py {args}'
    cmd = f'python /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py {args}'
    #!echo $cmd
    # !eval $cmd

    fn = f'{OUTDIR}/{MS_COMP_TYPE}_{FOCAL_TILE}_{SEASON_START}_{SEASON_STOP}_{YEAR_START}_{YEAR_STOP}_{STAT}{TARGET_SPECTRAL}.tif'
    if STAT == 'percentile':
        fn = f'{OUTDIR}/{MS_COMP_TYPE}_{FOCAL_TILE}_{SEASON_START}_{SEASON_STOP}_{YEAR_START}_{YEAR_STOP}_{STAT}{STAT_PCT}{TARGET_SPECTRAL}.tif'
    #rescaled_multiband_fn = os.path.join(os.path.dirname(fn), os.path.basename(fn).replace('.tif','_rescaled_3band_temp.tif'))
    # plotlib.rescale_multiband_for_plot(fn, rescaled_multiband_fn, bandlist = [5,7,3], pct=[20,90], nodata=-9999.0) 

    return fn

# %%
# Define input and output paths
INDEX_FN = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg' 
BASE_OUTDIR = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95'
# BASE_OUTDIR = '/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_ndvi_p95'

# %%
# Set default parameters
SAT_API = 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'
MS_COMP_TYPE = 'HLS'
HLS_PRODUCT = 'H30'

# STAT = 'max'
STAT = 'percentile'

# TARGET_SPECTRAL = 'ndvi'
TARGET_SPECTRAL = 'evi2'
STAT_PCT = 95.0

MIN_N_FILT_RESULTS = 10
MAX_CLOUDS = 0 # Threshold of max clouds to start search, e.g. when set to 0 it starts at 0% of cloud cover and go up to 90%

# %%
# Get first Layer name (First layer is used as default)
layer_names = fiona.listlayers(INDEX_FN)
# Get the first layer name
first_layer_name = layer_names[0]
INDEX_LYR = first_layer_name

# %%
# Define parameters
params = {
    'SAT_API': SAT_API,
    'HLS_PRODUCT': HLS_PRODUCT,
    'MS_COMP_TYPE': MS_COMP_TYPE,
    'MAX_CLOUDS': MAX_CLOUDS,
    'MIN_N_FILT_RESULTS': MIN_N_FILT_RESULTS,
    'STAT': STAT,
    'STAT_PCT': STAT_PCT,
    'TARGET_SPECTRAL': TARGET_SPECTRAL,
    'INDEX_FN': INDEX_FN,
    'INDEX_LYR': INDEX_LYR,
}

# %%
# Get all tiles IDs
with fiona.open(INDEX_FN, layer=0) as src:
    tiles = [feature["properties"]["tile_num"] for feature in src]
    
tiles_gpkg = gpd.read_file(INDEX_FN)
tiles = tiles_gpkg["tile_num"].tolist()
# # tiles

# %%
len(tiles)
# Out:
# 220

# %%
# Select tiles to run
# tiles_run = tiles

# tiles_run = tiles[3:4]
# tiles_run
tiles_run = [89,99]
# tiles_run = [99]

# %%
# years = [2018,2019,2020,2021,2022]
years = [2020,2022,2024]

# type(years)

# %%
# %%time
# Create parameter list and create output directories
# This is set up to do monthly composites
params_list = []
start_day = "01-01"
end_day = "12-31"

for tile in tiles_run: 
    for year in years:

        # output directory for specific run
        outdir = f'{BASE_OUTDIR}/tile_{tile:03d}/'
        
        os.makedirs(outdir, exist_ok=True)

        run_params = copy.deepcopy(params)
        # run_params = params.copy()
        run_params.update({
            'FOCAL_TILE': tile,
            'YEAR': year,
            'SEASON_START': start_day,
            'SEASON_STOP': end_day,
            'OUTDIR': str(outdir)
        })

        params_list.append(run_params)
# Out:
# CPU times: user 2.09 ms, sys: 69 µs, total: 2.16 ms
# Wall time: 118 ms

# %%
# len(params_list)
# params_list

# %%
params_list[0]
# Out:
# {'SAT_API': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#  'HLS_PRODUCT': 'H30',
#  'MS_COMP_TYPE': 'HLS',
#  'MAX_CLOUDS': 0,
#  'MIN_N_FILT_RESULTS': 10,
#  'STAT': 'percentile',
#  'STAT_PCT': 95.0,
#  'TARGET_SPECTRAL': 'evi2',
#  'INDEX_FN': '/projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg',
#  'INDEX_LYR': 'br_af_grid90km_prj',
#  'FOCAL_TILE': 89,
#  'YEAR': 2020,
#  'SEASON_START': '01-01',
#  'SEASON_STOP': '12-31',
#  'OUTDIR': '/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/'}

# %%
# params_list[0]#['SEASON_START'].split('-')[0]
# params_list[10:13]

# %%
# %%time
for params in params_list:
    try:
        print(f"Running tile {params['FOCAL_TILE']}, year {params['YEAR']}")
        output_file = wrapper_composite(params)
        print(f"Output saved to: {output_file}")
    except Exception as e:
        print(f"Error processing tile {params['FOCAL_TILE']}, year {params['YEAR']}: {e}")
# Out:
# Running tile 89, year 2020
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg
# Tile number:		 89
# Output res (m):		 30
# in_bbox:		 [5469419.049164498, 7224073.29125729, 5559419.049164498, 7314073.29125729]
# bbox 4326:		 [-49.378378833496065, -25.01637488893418, -48.45754764772649, -24.17719601338586]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		3000 x 3000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-49.378378833496065, -25.01637488893418, -48.45754764772649, -24.17719601338586]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2020-01-01T00:00:00Z 2020-12-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				15
# partial results (HLSS30_2.0):				19
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	34
#
# Search complete.
#
# 34
# HLS.L30.T22KGU.2020070T131636.v2.0
# HLS.L30.T22KFU.2020070T131636.v2.0
# HLS.L30.T22KFU.2020086T131628.v2.0
# HLS.L30.T22KGU.2020086T131628.v2.0
# HLS.L30.T22KFU.2020095T131012.v2.0
# HLS.L30.T22JFT.2020095T131036.v2.0
# HLS.L30.T22KGU.2020150T131611.v2.0
# HLS.L30.T22KFU.2020191T131022.v2.0
# HLS.L30.T22KGU.2020191T131022.v2.0
# HLS.L30.T22JGT.2020191T131046.v2.0
# HLS.L30.T22KFU.2020207T131027.v2.0
# HLS.L30.T22KGU.2020207T131027.v2.0
# HLS.L30.T22KFU.2020223T131030.v2.0
# HLS.L30.T22KGU.2020223T131030.v2.0
# HLS.L30.T22KFU.2020239T131039.v2.0
# HLS.S30.T22KFU.2020070T132231.v2.0
# HLS.S30.T22KFU.2020095T132229.v2.0
# HLS.S30.T22JFT.2020095T132229.v2.0
# HLS.S30.T22KFU.2020120T132241.v2.0
# HLS.S30.T22KGU.2020150T132241.v2.0
# HLS.S30.T22KFU.2020165T132239.v2.0
# HLS.S30.T22KGU.2020170T132241.v2.0
# HLS.S30.T22KFU.2020195T132239.v2.0
# HLS.S30.T22KGU.2020205T132239.v2.0
# HLS.S30.T22KFU.2020205T132239.v2.0
# HLS.S30.T22KGU.2020210T132241.v2.0
# HLS.S30.T22KFU.2020225T132239.v2.0
# HLS.S30.T22KGU.2020250T132241.v2.0
# HLS.S30.T22KFU.2020250T132241.v2.0
# HLS.S30.T22KFU.2020270T132241.v2.0
# HLS.S30.T22KGU.2020275T132239.v2.0
# HLS.S30.T22KFU.2020275T132239.v2.0
# HLS.S30.T22JGT.2020275T132239.v2.0
# HLS.S30.T22JFT.2020275T132239.v2.0
#
# Total # of scenes for composite:		34
# Creating evi2 stack with HLS ...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (34, 3000, 3000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# <class 'numpy.ndarray'>
# (3000, 3000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (3000, 3000)
# 		Valid Pixel Count: 9000000
# 		Mean: 10.07
# 		Standard Deviation: 7.21
# 		Minimum: -1.00
# 		Maximum: 33.00
# 		25th Percentile: 5.00
# 		50th Percentile (Median): 9.00
# 		75th Percentile: 17.00
# Count array min (0), max (34), and shape ((3000, 3000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -4.227722772277229
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 3000, 3000)
# Stack shape post-mask:		(23, 3000, 3000)
# 	Printing array stats: (23, 3000, 3000)
# 		Valid Pixel Count: 207000000
# 		Mean: 519475.52
# 		Standard Deviation: 1765373.88
# 		Minimum: -9999.00
# 		Maximum: 7314058.50
# 		25th Percentile: 0.06
# 		50th Percentile (Median): 0.41
# 		75th Percentile: 0.91
# Shape of input:			 (23, 3000, 3000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,3000,3000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,3000,3000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/13d46d0d-c026-46fc-bb1a-dbc6f7671b23/13d46d0d-c026-46fc-bb1a-dbc6f7671b23.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2020_2020_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2020_2020_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2020_2020_percentile95.0evi2.tif
#
# Output saved to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089//HLS_89_01-01_12-31_2020_2020_percentile95.0evi2.tif
# Running tile 89, year 2022
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg
# Tile number:		 89
# Output res (m):		 30
# in_bbox:		 [5469419.049164498, 7224073.29125729, 5559419.049164498, 7314073.29125729]
# bbox 4326:		 [-49.378378833496065, -25.01637488893418, -48.45754764772649, -24.17719601338586]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		3000 x 3000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-49.378378833496065, -25.01637488893418, -48.45754764772649, -24.17719601338586]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-01-01T00:00:00Z 2022-12-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				12
# partial results (HLSS30_2.0):				14
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	26
#
# Search complete.
#
# 26
# HLS.L30.T22KGU.2022115T131628.v2.0
# HLS.L30.T22KFU.2022172T131019.v2.0
# HLS.L30.T22JGT.2022211T131709.v2.0
# HLS.L30.T22KGU.2022227T131655.v2.0
# HLS.L30.T22KFU.2022227T131655.v2.0
# HLS.L30.T22JGT.2022227T131719.v2.0
# HLS.L30.T22KFU.2022244T131103.v2.0
# HLS.L30.T22JGT.2022251T131742.v2.0
# HLS.L30.T22KGU.2022299T131720.v2.0
# HLS.L30.T22KFU.2022299T131720.v2.0
# HLS.L30.T22JGT.2022299T131744.v2.0
# HLS.L30.T22JFT.2022299T131744.v2.0
# HLS.S30.T22KFU.2022059T132241.v2.0
# HLS.S30.T22JGT.2022059T132241.v2.0
# HLS.S30.T22JFT.2022059T132241.v2.0
# HLS.S30.T22KGU.2022149T132241.v2.0
# HLS.S30.T22KFU.2022164T132239.v2.0
# HLS.S30.T22KGU.2022174T132239.v2.0
# HLS.S30.T22KFU.2022174T132239.v2.0
# HLS.S30.T22KFU.2022184T132239.v2.0
# HLS.S30.T22KFU.2022239T132251.v2.0
# HLS.S30.T22KFU.2022244T132239.v2.0
# HLS.S30.T22KFU.2022299T132241.v2.0
# HLS.S30.T22JFT.2022299T132241.v2.0
# HLS.S30.T22KFU.2022314T132229.v2.0
# HLS.S30.T22JFT.2022319T132241.v2.0
#
# Total # of scenes for composite:		26
# Creating evi2 stack with HLS ...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (26, 3000, 3000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# <class 'numpy.ndarray'>
# (3000, 3000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (3000, 3000)
# 		Valid Pixel Count: 9000000
# 		Mean: 15.18
# 		Standard Deviation: 4.88
# 		Minimum: -1.00
# 		Maximum: 25.00
# 		25th Percentile: 13.00
# 		50th Percentile (Median): 14.00
# 		75th Percentile: 15.00
# Count array min (0), max (26), and shape ((3000, 3000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:556: RuntimeWarning: divide by zero encountered in divide
#   ndvi = (nir - red)/(nir + red )
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -inf
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 3000, 3000)
# Stack shape post-mask:		(23, 3000, 3000)
# 	Printing array stats: (23, 3000, 3000)
# 		Valid Pixel Count: 207000000
# 		Mean: -inf
# /opt/conda/envs/pangeo/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1882: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe', where=where)
# 		Standard Deviation: nan
# 		Minimum: -inf
# 		Maximum: 7314058.50
# 		25th Percentile: 0.15
# 		50th Percentile (Median): 0.46
# 		75th Percentile: 1.00
# Shape of input:			 (23, 3000, 3000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,3000,3000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,3000,3000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/92263382-9403-4487-aa37-fc103c9e42a9/92263382-9403-4487-aa37-fc103c9e42a9.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2022_2022_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2022_2022_percentile95.0evi2.tif
#
# Output saved to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089//HLS_89_01-01_12-31_2022_2022_percentile95.0evi2.tif
# Running tile 89, year 2024
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg
# Tile number:		 89
# Output res (m):		 30
# in_bbox:		 [5469419.049164498, 7224073.29125729, 5559419.049164498, 7314073.29125729]
# bbox 4326:		 [-49.378378833496065, -25.01637488893418, -48.45754764772649, -24.17719601338586]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		3000 x 3000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-49.378378833496065, -25.01637488893418, -48.45754764772649, -24.17719601338586]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2024-01-01T00:00:00Z 2024-12-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				24
# partial results (HLSS30_2.0):				13
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	37
#
# Search complete.
#
# 37
# HLS.L30.T22KGU.2024073T131652.v2.0
# HLS.L30.T22KFU.2024073T131652.v2.0
# HLS.L30.T22KGU.2024113T131610.v2.0
# HLS.L30.T22KFU.2024113T131610.v2.0
# HLS.L30.T22KGU.2024121T131619.v2.0
# HLS.L30.T22JGT.2024121T131643.v2.0
# HLS.L30.T22KFU.2024122T130952.v2.0
# HLS.L30.T22KGU.2024122T130952.v2.0
# HLS.L30.T22KGU.2024153T131605.v2.0
# HLS.L30.T22KFU.2024153T131605.v2.0
# HLS.L30.T22KGU.2024161T131548.v2.0
# HLS.L30.T22KFU.2024162T130951.v2.0
# HLS.L30.T22KGU.2024185T131557.v2.0
# HLS.L30.T22KFU.2024185T131557.v2.0
# HLS.L30.T22JGT.2024185T131621.v2.0
# HLS.L30.T22KFU.2024210T130959.v2.0
# HLS.L30.T22KGU.2024210T130959.v2.0
# HLS.L30.T22KGU.2024217T131613.v2.0
# HLS.L30.T22JGT.2024217T131637.v2.0
# HLS.L30.T22KFU.2024218T131006.v2.0
# HLS.L30.T22KGU.2024233T131625.v2.0
# HLS.L30.T22KFU.2024233T131625.v2.0
# HLS.L30.T22JGT.2024233T131649.v2.0
# HLS.L30.T22KFU.2024274T131027.v2.0
# HLS.S30.T22KGU.2024124T132229.v2.0
# HLS.S30.T22KGU.2024144T132229.v2.0
# HLS.S30.T22KFU.2024144T132229.v2.0
# HLS.S30.T22KFU.2024159T132241.v2.0
# HLS.S30.T22KFU.2024184T132239.v2.0
# HLS.S30.T22KFU.2024204T132239.v2.0
# HLS.S30.T22KFU.2024219T132231.v2.0
# HLS.S30.T22KGU.2024229T132231.v2.0
# HLS.S30.T22KFU.2024229T132231.v2.0
# HLS.S30.T22KFU.2024239T132231.v2.0
# HLS.S30.T22JFT.2024239T132231.v2.0
# HLS.S30.T22KFU.2024244T132239.v2.0
# HLS.S30.T22KFU.2024274T132239.v2.0
#
# Total # of scenes for composite:		37
# Creating evi2 stack with HLS ...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (37, 3000, 3000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# <class 'numpy.ndarray'>
# (3000, 3000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (3000, 3000)
# 		Valid Pixel Count: 9000000
# 		Mean: 14.44
# 		Standard Deviation: 15.21
# 		Minimum: -1.00
# 		Maximum: 36.00
# 		25th Percentile: -1.00
# 		50th Percentile (Median): 7.00
# 		75th Percentile: 34.00
# Count array min (0), max (37), and shape ((3000, 3000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.7081545064377682
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 3000, 3000)
# Stack shape post-mask:		(23, 3000, 3000)
# 	Printing array stats: (23, 3000, 3000)
# 		Valid Pixel Count: 207000000
# 		Mean: 368306.10
# 		Standard Deviation: 1510857.02
# 		Minimum: -9999.00
# 		Maximum: 7314058.50
# 		25th Percentile: -9999.00
# 		50th Percentile (Median): 0.14
# 		75th Percentile: 0.55
# Shape of input:			 (23, 3000, 3000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,3000,3000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,3000,3000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/5cd43772-d7ae-401e-9a27-805604292896/5cd43772-d7ae-401e-9a27-805604292896.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2024_2024_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2024_2024_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089/HLS_89_01-01_12-31_2024_2024_percentile95.0evi2.tif
#
# Output saved to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_089//HLS_89_01-01_12-31_2024_2024_percentile95.0evi2.tif
# Running tile 99, year 2020
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg
# Tile number:		 99
# Output res (m):		 30
# in_bbox:		 [5559419.049164498, 7224073.29125729, 5649419.049164498, 7314073.29125729]
# bbox 4326:		 [-48.49313341603107, -24.985935209695654, -47.56711083608765, -24.142829840739935]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		3000 x 3000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-48.49313341603107, -24.985935209695654, -47.56711083608765, -24.142829840739935]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2020-01-01T00:00:00Z 2020-12-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				14
# partial results (HLSS30_2.0):				38
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	52
#
# Search complete.
#
# 52
# HLS.L30.T23KKP.2020120T130350.v2.0
# HLS.L30.T22KHU.2020120T130350.v2.0
# HLS.L30.T22KHU.2020152T130351.v2.0
# HLS.L30.T23KKP.2020152T130351.v2.0
# HLS.L30.T22JHT.2020159T131030.v2.0
# HLS.L30.T23JKN.2020159T131030.v2.0
# HLS.L30.T22KGU.2020191T131022.v2.0
# HLS.L30.T22JGT.2020191T131046.v2.0
# HLS.L30.T22KHU.2020207T131027.v2.0
# HLS.L30.T22KGU.2020207T131027.v2.0
# HLS.L30.T23KKP.2020207T131027.v2.0
# HLS.L30.T22KGU.2020223T131030.v2.0
# HLS.L30.T22JHT.2020287T131116.v2.0
# HLS.L30.T23JKN.2020287T131116.v2.0
# HLS.S30.T22JHT.2020007T131241.v2.0
# HLS.S30.T23JKN.2020007T131241.v2.0
# HLS.S30.T22KHU.2020027T131241.v2.0
# HLS.S30.T23KKP.2020027T131241.v2.0
# HLS.S30.T22JHT.2020027T131241.v2.0
# HLS.S30.T23JKN.2020027T131241.v2.0
# HLS.S30.T22KHU.2020097T131241.v2.0
# HLS.S30.T23KKP.2020097T131241.v2.0
# HLS.S30.T22KHU.2020120T132241.v2.0
# HLS.S30.T23KKP.2020120T132241.v2.0
# HLS.S30.T22KHU.2020132T131239.v2.0
# HLS.S30.T23KKP.2020132T131239.v2.0
# HLS.S30.T22JHT.2020132T131239.v2.0
# HLS.S30.T23JKN.2020132T131239.v2.0
# HLS.S30.T22KHU.2020150T132241.v2.0
# HLS.S30.T23KKP.2020150T132241.v2.0
# HLS.S30.T22KGU.2020150T132241.v2.0
# HLS.S30.T22KHU.2020152T131249.v2.0
# HLS.S30.T23KKP.2020152T131249.v2.0
# HLS.S30.T22KHU.2020170T132241.v2.0
# HLS.S30.T23KKP.2020170T132241.v2.0
# HLS.S30.T22KGU.2020170T132241.v2.0
# HLS.S30.T22KHU.2020172T131249.v2.0
# HLS.S30.T23KKP.2020172T131249.v2.0
# HLS.S30.T22JHT.2020172T131249.v2.0
# HLS.S30.T23JKN.2020172T131249.v2.0
# HLS.S30.T23KKP.2020205T132239.v2.0
# HLS.S30.T22KGU.2020205T132239.v2.0
# HLS.S30.T22KHU.2020207T131251.v2.0
# HLS.S30.T23KKP.2020207T131251.v2.0
# HLS.S30.T22KGU.2020210T132241.v2.0
# HLS.S30.T22KHU.2020247T131251.v2.0
# HLS.S30.T23KKP.2020247T131251.v2.0
# HLS.S30.T22KGU.2020250T132241.v2.0
# HLS.S30.T22KGU.2020275T132239.v2.0
# HLS.S30.T22JGT.2020275T132239.v2.0
# HLS.S30.T22KHU.2020302T131249.v2.0
# HLS.S30.T23KKP.2020302T131249.v2.0
#
# Total # of scenes for composite:		52
# Creating evi2 stack with HLS ...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (52, 3000, 3000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# <class 'numpy.ndarray'>
# (3000, 3000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (3000, 3000)
# 		Valid Pixel Count: 9000000
# 		Mean: 12.84
# 		Standard Deviation: 11.75
# 		Minimum: -1.00
# 		Maximum: 51.00
# 		25th Percentile: 6.00
# 		50th Percentile (Median): 7.00
# 		75th Percentile: 22.00
# Count array min (0), max (41), and shape ((3000, 3000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -2.5955056179775284
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 3000, 3000)
# Stack shape post-mask:		(23, 3000, 3000)
# 	Printing array stats: (23, 3000, 3000)
# 		Valid Pixel Count: 207000000
# 		Mean: 512023.52
# 		Standard Deviation: 1758979.83
# 		Minimum: -9999.00
# 		Maximum: 7314058.50
# 		25th Percentile: 0.05
# 		50th Percentile (Median): 0.41
# 		75th Percentile: 0.89
# Shape of input:			 (23, 3000, 3000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,3000,3000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,3000,3000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/a4022628-f98f-435a-a314-63846807cc22/a4022628-f98f-435a-a314-63846807cc22.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2020_2020_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2020_2020_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2020_2020_percentile95.0evi2.tif
#
# Output saved to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099//HLS_99_01-01_12-31_2020_2020_percentile95.0evi2.tif
# Running tile 99, year 2022
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg
# Tile number:		 99
# Output res (m):		 30
# in_bbox:		 [5559419.049164498, 7224073.29125729, 5649419.049164498, 7314073.29125729]
# bbox 4326:		 [-48.49313341603107, -24.985935209695654, -47.56711083608765, -24.142829840739935]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		3000 x 3000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-48.49313341603107, -24.985935209695654, -47.56711083608765, -24.142829840739935]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2022-01-01T00:00:00Z 2022-12-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				7
# partial results (HLSS30_2.0):				22
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	29
#
# Search complete.
#
# 29
# HLS.L30.T22KHU.2022149T130352.v2.0
# HLS.L30.T23KKP.2022149T130352.v2.0
# HLS.L30.T22JGT.2022149T130416.v2.0
# HLS.L30.T23KKP.2022245T130435.v2.0
# HLS.L30.T22KHU.2022245T130435.v2.0
# HLS.L30.T23JKN.2022300T131123.v2.0
# HLS.L30.T22JHT.2022300T131123.v2.0
# HLS.S30.T22KHU.2022059T132241.v2.0
# HLS.S30.T23KKP.2022059T132241.v2.0
# HLS.S30.T22JGT.2022059T132241.v2.0
# HLS.S30.T22KHU.2022089T132241.v2.0
# HLS.S30.T23KKP.2022089T132241.v2.0
# HLS.S30.T22JHT.2022089T132241.v2.0
# HLS.S30.T23JKN.2022089T132241.v2.0
# HLS.S30.T22KHU.2022141T131239.v2.0
# HLS.S30.T22KHU.2022146T131251.v2.0
# HLS.S30.T23KKP.2022146T131251.v2.0
# HLS.S30.T22KHU.2022149T132241.v2.0
# HLS.S30.T23KKP.2022149T132241.v2.0
# HLS.S30.T22KGU.2022149T132241.v2.0
# HLS.S30.T22JHT.2022149T132241.v2.0
# HLS.S30.T23JKN.2022149T132241.v2.0
# HLS.S30.T22KHU.2022174T132239.v2.0
# HLS.S30.T23KKP.2022174T132239.v2.0
# HLS.S30.T22KGU.2022174T132239.v2.0
# HLS.S30.T22KHU.2022184T132239.v2.0
# HLS.S30.T23KKP.2022184T132239.v2.0
# HLS.S30.T22JHT.2022184T132239.v2.0
# HLS.S30.T23JKN.2022184T132239.v2.0
#
# Total # of scenes for composite:		29
# Creating evi2 stack with HLS ...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (29, 3000, 3000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# <class 'numpy.ndarray'>
# (3000, 3000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (3000, 3000)
# 		Valid Pixel Count: 9000000
# 		Mean: 10.94
# 		Standard Deviation: 5.11
# 		Minimum: -1.00
# 		Maximum: 28.00
# 		25th Percentile: 9.00
# 		50th Percentile (Median): 9.00
# 		75th Percentile: 13.00
# Count array min (0), max (25), and shape ((3000, 3000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -0.3930348258706468
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 3000, 3000)
# Stack shape post-mask:		(23, 3000, 3000)
# 	Printing array stats: (23, 3000, 3000)
# 		Valid Pixel Count: 207000000
# 		Mean: 531824.12
# 		Standard Deviation: 1788895.53
# 		Minimum: -9999.00
# 		Maximum: 7314058.50
# 		25th Percentile: 0.07
# 		50th Percentile (Median): 0.46
# 		75th Percentile: 0.91
# Shape of input:			 (23, 3000, 3000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,3000,3000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,3000,3000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/a436fa80-8894-4d24-bb60-2de7829c84de/a436fa80-8894-4d24-bb60-2de7829c84de.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2022_2022_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2022_2022_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2022_2022_percentile95.0evi2.tif
#
# Output saved to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099//HLS_99_01-01_12-31_2022_2022_percentile95.0evi2.tif
# Running tile 99, year 2024
#
# Tiles path:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/shp/atlantic_forest/tiles/br_af_grid90km_prj.gpkg
# Tile number:		 99
# Output res (m):		 30
# in_bbox:		 [5559419.049164498, 7224073.29125729, 5649419.049164498, 7314073.29125729]
# bbox 4326:		 [-48.49313341603107, -24.985935209695654, -47.56711083608765, -24.142829840739935]
# Getting output dims from buffered (buffer=0.0) original tile geometry...
# Output dims:		3000 x 3000
# Composite type:		HLS
#
# Getting HLS Surface Reflectance H30 data...
# bbox: [-48.49313341603107, -24.985935209695654, -47.56711083608765, -24.142829840739935]
#
# Querying STAC for multispectral imagery...
# Catalog title: LPCLOUD STAC Catalog
# start date, end date:		 2024-01-01T00:00:00Z 2024-12-31T23:59:59Z
#
# Conducting multispectral image search now ...
# Searching for:			['HLSL30_2.0', 'HLSS30_2.0']
# Max cloudcover threshold starts at: 0% and won't exceed 90%
# Min number of filtered results: 10
# partial results (HLSL30_2.0):				10
# partial results (HLSS30_2.0):				16
# compelte results (['HLSL30_2.0', 'HLSS30_2.0']):	26
#
# Search complete.
#
# 26
# HLS.L30.T22KHU.2024122T130952.v2.0
# HLS.L30.T23KKP.2024122T130952.v2.0
# HLS.L30.T22KGU.2024122T130952.v2.0
# HLS.L30.T23KKP.2024163T130326.v2.0
# HLS.L30.T22KHU.2024163T130326.v2.0
# HLS.L30.T22KHU.2024171T130328.v2.0
# HLS.L30.T23KKP.2024171T130328.v2.0
# HLS.L30.T23JKN.2024171T130352.v2.0
# HLS.L30.T22JHT.2024171T130352.v2.0
# HLS.L30.T22KGU.2024210T130959.v2.0
# HLS.S30.T23JKN.2024081T131239.v2.0
# HLS.S30.T22KGU.2024124T132229.v2.0
# HLS.S30.T22KHU.2024144T132229.v2.0
# HLS.S30.T23KKP.2024144T132229.v2.0
# HLS.S30.T22KGU.2024144T132229.v2.0
# HLS.S30.T22KHU.2024169T132241.v2.0
# HLS.S30.T23KKP.2024169T132241.v2.0
# HLS.S30.T22KHU.2024171T131249.v2.0
# HLS.S30.T23KKP.2024171T131249.v2.0
# HLS.S30.T22JHT.2024171T131249.v2.0
# HLS.S30.T23JKN.2024171T131249.v2.0
# HLS.S30.T22KGU.2024229T132231.v2.0
# HLS.S30.T22JHT.2024256T131241.v2.0
# HLS.S30.T23JKN.2024256T131241.v2.0
# HLS.S30.T22JHT.2024351T131239.v2.0
# HLS.S30.T23JKN.2024351T131239.v2.0
#
# Total # of scenes for composite:		26
# Creating evi2 stack with HLS ...
#
# Finished created masked evi2 stack.
#
# Make evi2 masked array
# shape:		 (26, 3000, 3000)
#
# Calculating index positions from evi2 stack using stat: percentile (w/ nodatavalue = -9999)...
# 	Apply the mask for no data values...
# <class 'numpy.ndarray'>
# (3000, 3000)
# 	Statistical summary of index array for stat=percentile
# 	Printing array stats: (3000, 3000)
# 		Valid Pixel Count: 9000000
# 		Mean: 3.37
# 		Standard Deviation: 6.39
# 		Minimum: -1.00
# 		Maximum: 25.00
# 		25th Percentile: -1.00
# 		50th Percentile (Median): 0.00
# 		75th Percentile: 8.00
# Count array min (0), max (21), and shape ((3000, 3000))
# Create LUT of evi2 positions using stat=percentile
# Creating Blue composite...
# Creating Green composite...
# Creating Red composite...
# Creating NIR composite...
# Creating SWIR composite...
# Creating SWIR2 composite...
# Creating Julian Date composite...
# Creating Year Date composite...
# Creating Fmask composite...
# 	NDVI Created
#
# Generating a valid mask using min NDVI threshold (-1.0) on NDVI composite...
# Creating binary vegetation mask where NDVI > -1.0 indicates valid data, set to 1, all else 0...
# 	min NDVI value before mask: -1.1791044776119404
#
# Generating spectral indices...
# 	SAVI Created
# 	MSAVI Created
# 	NDMI Created
# 	EVI Created
# 	NBR Created
# 	NBR2 Created
# 	TassCap Created
#
# Creating raster stack...
#
# Calculating X and Y pixel center coords...
# Assigning band names:
# 	['Blue', 'Green', 'Red', 'NIR', 'SWIR', 'SWIR2', 'NDVI', 'SAVI', 'MSAVI', 'NDMI', 'EVI', 'EVI2', 'NBR', 'NBR2', 'TCB', 'TCG', 'TCW', 'ValidMask', 'Xgeo', 'Ygeo', 'JulianDate', 'yearDate', 'count']
#
# specifying output directory and filename
#
# Apply a common mask across all layers of stack...
# Stack shape pre-mask:		(23, 3000, 3000)
# Stack shape post-mask:		(23, 3000, 3000)
# 	Printing array stats: (23, 3000, 3000)
# 		Valid Pixel Count: 207000000
# 		Mean: 282599.84
# 		Standard Deviation: 1343301.61
# 		Minimum: -9999.00
# 		Maximum: 7314058.50
# 		25th Percentile: -9999.00
# 		50th Percentile (Median): -0.03
# 		75th Percentile: 0.47
# Shape of input:			 (23, 3000, 3000)
# Resampling:			 0	[0=nearest, 1=blinear, 2=cubic]
# Shape after clip & transform:	 (23,3000,3000)
# Output resolution:		 (30, 30)
# Writing img to memory...
# /projects/my-private-bucket/code-git-shared/icesat2_boreal/lib/build_ms_composite_addEVI2.py:987: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(stack,
# Current stack shape:		(23,3000,3000)
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/a58e215c-bed7-454f-b3da-ba16f4447477/a58e215c-bed7-454f-b3da-ba16f4447477.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2024_2024_percentile95.0evi2.tif
# Image written to disk:		 /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2024_2024_percentile95.0evi2.tif
# Wrote out stack:		/projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099/HLS_99_01-01_12-31_2024_2024_percentile95.0evi2.tif
#
# Output saved to: /projects/my-private-bucket/HLS-1DCNN-AGB/data/tif/HLS_composites/yearly/br_af_grid90km_evi2_p95/tile_099//HLS_99_01-01_12-31_2024_2024_percentile95.0evi2.tif
# CPU times: user 58.8 s, sys: 24.4 s, total: 1min 23s
# Wall time: 2h 4min 3s

# %%
## NOTES

# 1 tile 2 years
# Wall time: 1h 5min 14s
# 1 tile 1 year br_af_grid30km_prj.gpkg
# Wall time: ~36min

# %%
output_file

# %% [markdown]
# ## MULTIPROCESSING - Error with multiple requests

# %%
# %%time
# mp.cpu_count() - 1
# with mp.Pool(processes= 5) as pool:
#     fn_list = pool.map(wrapper_composite, params_list)
with mp.Pool(processes= 12) as pool:
    fn_list = pool.map(wrapper_composite, params_list)

# %%
# # Plotting to check false composite to check
# fn = fn_list[0]
# fn
# rescaled_multiband_fn = fn.replace('.tif', '_rescaled_3band_temp.tif')
# plotlib.rescale_multiband_for_plot(fn, rescaled_multiband_fn, bandlist = [6,4,3], pct=[20,98], nodata=-9999.0) 

# fig,ax=plt.subplots(figsize=(10,10))
# with rasterio.open(rescaled_multiband_fn) as src:
#     #print(src.profile)
#     show(src.read(),transform=src.transform, ax=ax, title=os.path.basename(rescaled_multiband_fn))

# %%
### Notes

# Time to run 1 tile 1 year 12 processors

# %%
## CHECK ERRORS

## No output is created sometimes when runnning multiple jobs
